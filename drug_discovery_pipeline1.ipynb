# %% [markdown]
# # Drug Discovery Pipeline
# ## Quantum-Enhanced Multimodal Drug Discovery with Graph Neural Networks
#
# ### Architecture Overview
# ```
# Multimodal Embeddings ──→ Transfer Learning ──→ Core Neural ──→ Model Engines ──→ Generation & Prediction
#      from P1                Module + PTMs       Architectures     ├─ Graph Diffusion   ├─ De Novo SMILES
#                                                     │             │  Engine (DiffRM)    │  Generation
# Activity & ADMET ──→ PyTorch & PyG                  │             └─ Equivariant GNN   └─ Binding Affinity
#     Scoring            Training Pipeline             │                                     Predictor
#                                                      ▼
#                                               Optimized Candidate Molecules
# ```
#
# ### Datasets
# | Dataset | Records | Purpose |
# |---------|---------|--------|
# | drug_cleaned.csv | 76,543 | Docking scores + molecular descriptors |
# | drug_filtered.csv | 637,292 | Filtered drug candidates |
# | interactions_cleaned.csv | 750 | Drug-protein interactions |
# | drug_protein_diagnosis.csv | 99 | Drug-protein binding with diagnosis |
# | tox21_cleaned.csv | 7,831 | Toxicity assay data (12 endpoints) |
# | clintox.csv | 1,484 | Clinical toxicity (FDA approval + CT toxicity) |

# %% [markdown]
# ---
# ## 1. Setup & Installation

# %%
# Install required packages (uncomment as needed)
# !pip install torch torch-geometric rdkit scikit-learn pandas numpy matplotlib seaborn tqdm
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.10.0+cu128)
# Requirement already satisfied: torch-geometric in /usr/local/lib/python3.12/dist-packages (2.7.0)
# Requirement already satisfied: rdkit in /usr/local/lib/python3.12/dist-packages (2025.9.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch) (1.4.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from torch-geometric) (3.13.3)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from torch-geometric) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from torch-geometric) (3.3.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from torch-geometric) (2.32.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from torch-geometric) (3.6.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from rdkit) (11.3.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (26.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric) (1.22.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->torch-geometric) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->torch-geometric) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->torch-geometric) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->torch-geometric) (2026.2.25)

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import defaultdict
import warnings
warnings.filterwarnings('ignore')

# PyTorch
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.optim.lr_scheduler import CosineAnnealingLR

# PyTorch Geometric
import torch_geometric
from torch_geometric.data import Data, Batch
from torch_geometric.nn import GCNConv, GATConv, global_mean_pool, global_add_pool
from torch_geometric.loader import DataLoader as PyGDataLoader

# RDKit for molecular processing
from rdkit import Chem
from rdkit.Chem import AllChem, Descriptors, Draw, DataStructs
from rdkit.Chem import rdMolDescriptors

# Scikit-learn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (roc_auc_score, accuracy_score, mean_squared_error,
                             classification_report, r2_score)

from tqdm.auto import tqdm

DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {DEVICE}')
print(f'PyTorch version: {torch.__version__}')
print(f'PyG version: {torch_geometric.__version__}')
# Out:
# Using device: cuda
# PyTorch version: 2.10.0+cu128
# PyG version: 2.7.0

# %% [markdown]
# ---
# ## 2. Data Loading & Exploration

# %%
# Load all datasets
DATA_DIR = '.'

drug_cleaned = pd.read_csv(os.path.join(DATA_DIR, '/content/drug_cleaned.csv'))
drug_filtered = pd.read_csv(os.path.join(DATA_DIR, '/content/drug_filtered.csv'))
interactions = pd.read_csv(os.path.join(DATA_DIR, '/content/interactions_cleaned.csv'))
drug_protein = pd.read_csv(os.path.join(DATA_DIR, '/content/drug_protein_diagnosis.csv'))
tox21 = pd.read_csv(os.path.join(DATA_DIR, '/content/tox21_cleaned.csv'))
clintox = pd.read_csv(os.path.join(DATA_DIR, '/content/clintox.csv'))

print('=== Dataset Shapes ===')
for name, df in [('drug_cleaned', drug_cleaned), ('drug_filtered', drug_filtered),
                  ('interactions', interactions), ('drug_protein', drug_protein),
                  ('tox21', tox21), ('clintox', clintox)]:
    print(f'{name:30s} → {df.shape[0]:>8,} rows × {df.shape[1]:>3} cols')
# Out:
# === Dataset Shapes ===
# drug_cleaned                   →   76,543 rows ×  16 cols
# drug_filtered                  →  637,292 rows ×  16 cols
# interactions                   →      750 rows ×  16 cols
# drug_protein                   →       99 rows ×   7 cols
# tox21                          →    7,831 rows ×  16 cols
# clintox                        →    1,484 rows ×   3 cols

# %%
# Quick EDA
fig, axes = plt.subplots(2, 3, figsize=(18, 10))

# 1. Docking score distribution
axes[0, 0].hist(drug_cleaned['score'], bins=50, color='steelblue', edgecolor='black', alpha=0.7)
axes[0, 0].set_title('Docking Scores (drug_cleaned)')
axes[0, 0].set_xlabel('Score')

# 2. MW distribution
axes[0, 1].hist(drug_cleaned['MW'], bins=50, color='coral', edgecolor='black', alpha=0.7)
axes[0, 1].set_title('Molecular Weight Distribution')
axes[0, 1].axvline(x=500, color='red', linestyle='--', label='Lipinski MW<500')
axes[0, 1].legend()

# 3. Toxicity score distribution (tox21)
axes[0, 2].hist(tox21['toxicity_score'], bins=range(0, 14), color='darkred', edgecolor='black', alpha=0.7)
axes[0, 2].set_title('Tox21 Toxicity Scores')
axes[0, 2].set_xlabel('Number of toxic endpoints')

# 4. Binding affinity distribution
axes[1, 0].hist(drug_protein['binding_affinity'], bins=20, color='forestgreen', edgecolor='black', alpha=0.7)
axes[1, 0].set_title('Binding Affinities (drug_protein)')
axes[1, 0].set_xlabel('Binding Affinity')

# 5. Interaction types
interactions['interaction_type'].value_counts().plot.bar(ax=axes[1, 1], color='mediumpurple')
axes[1, 1].set_title('Interaction Types')
axes[1, 1].tick_params(axis='x', rotation=45)

# 6. ClinTox FDA approval vs toxicity
clintox_summary = clintox[['FDA_APPROVED', 'CT_TOX']].sum()
clintox_summary.plot.bar(ax=axes[1, 2], color=['green', 'red'])
axes[1, 2].set_title('ClinTox: FDA Approved vs CT Toxic')
axes[1, 2].tick_params(axis='x', rotation=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## 3. Multimodal Embeddings from P1
# Generate molecular graph representations and fingerprint embeddings from SMILES.

# %%
# ─── Atom and Bond Feature Extraction ───

ATOM_FEATURES = {
    'atomic_num': list(range(1, 119)),
    'degree': [0, 1, 2, 3, 4, 5],
    'formal_charge': [-2, -1, 0, 1, 2],
    'hybridization': [
        Chem.rdchem.HybridizationType.SP,
        Chem.rdchem.HybridizationType.SP2,
        Chem.rdchem.HybridizationType.SP3,
        Chem.rdchem.HybridizationType.SP3D,
        Chem.rdchem.HybridizationType.SP3D2
    ],
    'num_hs': [0, 1, 2, 3, 4],
}

def one_hot_encode(value, choices):
    """One-hot encode a value given a list of possible choices."""
    encoding = [0] * (len(choices) + 1)  # +1 for unknown
    if value in choices:
        encoding[choices.index(value)] = 1
    else:
        encoding[-1] = 1
    return encoding


def get_atom_features(atom):
    """Extract atom-level features as a vector."""
    features = []
    features += one_hot_encode(atom.GetAtomicNum(), ATOM_FEATURES['atomic_num'])
    features += one_hot_encode(atom.GetDegree(), ATOM_FEATURES['degree'])
    features += one_hot_encode(atom.GetFormalCharge(), ATOM_FEATURES['formal_charge'])
    features += one_hot_encode(atom.GetHybridization(), ATOM_FEATURES['hybridization'])
    features += one_hot_encode(atom.GetTotalNumHs(), ATOM_FEATURES['num_hs'])
    features.append(1 if atom.GetIsAromatic() else 0)
    features.append(atom.GetMass() / 100.0)  # normalized mass
    return features


def get_bond_features(bond):
    """Extract bond-level features."""
    bt = bond.GetBondType()
    features = [
        bt == Chem.rdchem.BondType.SINGLE,
        bt == Chem.rdchem.BondType.DOUBLE,
        bt == Chem.rdchem.BondType.TRIPLE,
        bt == Chem.rdchem.BondType.AROMATIC,
        bond.GetIsConjugated(),
        bond.IsInRing()
    ]
    return [int(f) for f in features]


print(f'Atom feature dimension: {len(get_atom_features(Chem.MolFromSmiles("C").GetAtomWithIdx(0)))}')
# Out:
# Atom feature dimension: 146

# %%
# ─── SMILES → PyG Graph Conversion ───

def smiles_to_graph(smiles, y=None):
    """Convert a SMILES string to a PyG Data object with atom/bond features."""
    mol = Chem.MolFromSmiles(smiles)
    if mol is None:
        return None

    # Atom features
    atom_feats = [get_atom_features(atom) for atom in mol.GetAtoms()]
    x = torch.tensor(atom_feats, dtype=torch.float)

    # Edge index and edge features
    edge_index = []
    edge_attr = []
    for bond in mol.GetBonds():
        i, j = bond.GetBeginAtomIdx(), bond.GetEndAtomIdx()
        edge_index += [[i, j], [j, i]]
        bf = get_bond_features(bond)
        edge_attr += [bf, bf]

    if len(edge_index) == 0:
        edge_index = torch.zeros((2, 0), dtype=torch.long)
        edge_attr = torch.zeros((0, 6), dtype=torch.float)
    else:
        edge_index = torch.tensor(edge_index, dtype=torch.long).t().contiguous()
        edge_attr = torch.tensor(edge_attr, dtype=torch.float)

    data = Data(x=x, edge_index=edge_index, edge_attr=edge_attr)
    data.smiles = smiles

    if y is not None:
        data.y = torch.tensor([y], dtype=torch.float)

    return data


# Test conversion
test_graph = smiles_to_graph('CCO')
print(f'Test graph: {test_graph}')
print(f'  Nodes: {test_graph.num_nodes}, Edges: {test_graph.num_edges}')
print(f'  Node feature dim: {test_graph.x.shape[1]}')
# Out:
# Test graph: Data(x=[3, 146], edge_index=[2, 4], edge_attr=[4, 6], smiles='CCO')
#   Nodes: 3, Edges: 4
#   Node feature dim: 146

# %%
# ─── Multimodal Molecular Embedding (Fingerprints + Descriptors) ───

def get_morgan_fingerprint(smiles, radius=2, n_bits=2048):
    """Generate Morgan fingerprint (ECFP) for a SMILES string."""
    mol = Chem.MolFromSmiles(smiles)
    if mol is None:
        return np.zeros(n_bits)
    gen = AllChem.GetMorganGenerator(radius=radius, fpSize=n_bits)
    fp = gen.GetFingerprintAsNumPy(mol)
    return fp.astype(np.float32)


def get_molecular_descriptors(smiles):
    """Compute physicochemical descriptors for a molecule."""
    mol = Chem.MolFromSmiles(smiles)
    if mol is None:
        return np.zeros(10)
    return np.array([
        Descriptors.MolWt(mol),
        Descriptors.MolLogP(mol),
        Descriptors.TPSA(mol),
        Descriptors.NumHDonors(mol),
        Descriptors.NumHAcceptors(mol),
        Descriptors.NumRotatableBonds(mol),
        Descriptors.RingCount(mol),
        Descriptors.FractionCSP3(mol),
        Descriptors.NumAromaticRings(mol),
        Descriptors.HeavyAtomCount(mol)
    ], dtype=np.float32)


def get_multimodal_embedding(smiles, fp_bits=2048):
    """Concatenate fingerprint + descriptors into a single embedding vector."""
    fp = get_morgan_fingerprint(smiles, n_bits=fp_bits)
    desc = get_molecular_descriptors(smiles)
    return np.concatenate([fp, desc])


# Demo
emb = get_multimodal_embedding('CCO')
print(f'Multimodal embedding dimension: {len(emb)} (2048 FP + 10 descriptors)')
# Demo
# Out:
# Multimodal embedding dimension: 2058 (2048 FP + 10 descriptors)

# %% [markdown]
# ---
# ## 4. Transfer Learning Module → Pre-trained Foundation Models
# A transfer learning encoder that learns latent molecular representations. Pre-trained on large-scale molecular data and fine-tuned for downstream tasks.

# %%
# ─── Pre-trained Molecular Encoder (Foundation Model) ───

class MolecularFoundationEncoder(nn.Module):
    """Foundation model: encodes multimodal molecular embeddings into a
    latent space. Can be pre-trained then frozen for transfer learning."""

    def __init__(self, input_dim=2058, hidden_dim=512, latent_dim=256, dropout=0.2):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.BatchNorm1d(hidden_dim),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim, hidden_dim // 2),
            nn.BatchNorm1d(hidden_dim // 2),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim // 2, latent_dim),
        )
        # Decoder for pre-training (reconstruction)
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, hidden_dim // 2),
            nn.ReLU(),
            nn.Linear(hidden_dim // 2, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, input_dim),
        )

    def encode(self, x):
        return self.encoder(x)

    def forward(self, x):
        z = self.encoder(x)
        recon = self.decoder(z)
        return z, recon


class TransferLearningModule(nn.Module):
    """Wraps the foundation encoder w/ a fine-tuning head for any downstream task."""

    def __init__(self, foundation_encoder, latent_dim=256, output_dim=1, freeze_encoder=True):
        super().__init__()
        self.foundation = foundation_encoder
        if freeze_encoder:
            for param in self.foundation.encoder.parameters():
                param.requires_grad = False
        self.head = nn.Sequential(
            nn.Linear(latent_dim, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, output_dim)
        )

    def forward(self, x):
        z = self.foundation.encode(x)
        return self.head(z)


print('Foundation Encoder parameters:', sum(p.numel() for p in MolecularFoundationEncoder().parameters()))
# Out:
# Foundation Encoder parameters: 2505994

# %%
# ─── Pre-train the Foundation Encoder (Autoencoder on drug SMILES) ───

class MolEmbeddingDataset(Dataset):
    def __init__(self, smiles_list, fp_bits=2048):
        self.embeddings = []
        for smi in tqdm(smiles_list, desc='Building embeddings'):
            emb = get_multimodal_embedding(smi, fp_bits=fp_bits)
            self.embeddings.append(emb)
        self.embeddings = np.array(self.embeddings)
        # Normalize descriptors (last 10 features)
        self.scaler = StandardScaler()
        self.embeddings[:, -10:] = self.scaler.fit_transform(self.embeddings[:, -10:])

    def __len__(self):
        return len(self.embeddings)

    def __getitem__(self, idx):
        return torch.tensor(self.embeddings[idx], dtype=torch.float)


# Use a sample of drug_cleaned for pre-training
pretrain_smiles = drug_cleaned['SMILES'].dropna().sample(n=min(10000, len(drug_cleaned)), random_state=42).tolist()
pretrain_dataset = MolEmbeddingDataset(pretrain_smiles)
pretrain_loader = DataLoader(pretrain_dataset, batch_size=256, shuffle=True)

print(f'Pre-training on {len(pretrain_dataset)} molecules')
# Out:
# Building embeddings:   0%|          | 0/10000 [00:00<?, ?it/s]
# [16:53:16] Conflicting single bond directions around double bond at index 5.
# [16:53:16]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:53:16] Conflicting single bond directions around double bond at index 5.
# [16:53:16]   BondStereo set to STEREONONE and single bond directions set to NONE.
# Pre-training on 10000 molecules

# %%
# ─── Pre-training Loop ───

foundation_model = MolecularFoundationEncoder(input_dim=2058, latent_dim=256).to(DEVICE)
optimizer_pt = torch.optim.Adam(foundation_model.parameters(), lr=1e-3)

PRETRAIN_EPOCHS = 30
pretrain_losses = []

for epoch in range(1, PRETRAIN_EPOCHS + 1):
    foundation_model.train()
    epoch_loss = 0
    for batch in pretrain_loader:
        batch = batch.to(DEVICE)
        z, recon = foundation_model(batch)
        loss = F.mse_loss(recon, batch)
        optimizer_pt.zero_grad()
        loss.backward()
        optimizer_pt.step()
        epoch_loss += loss.item() * batch.size(0)
    epoch_loss /= len(pretrain_dataset)
    pretrain_losses.append(epoch_loss)
    if epoch % 5 == 0:
        print(f'  Epoch {epoch:3d}/{PRETRAIN_EPOCHS} │ Recon Loss: {epoch_loss:.6f}')

plt.figure(figsize=(8, 4))
plt.plot(pretrain_losses, color='royalblue')
plt.xlabel('Epoch'); plt.ylabel('Reconstruction Loss')
plt.title('Foundation Model Pre-training')
plt.grid(True, alpha=0.3)
plt.show()

print('Foundation model pre-training complete.')
# Out:
#   Epoch   5/30 │ Recon Loss: 0.014429
#   Epoch  10/30 │ Recon Loss: 0.013206
#   Epoch  15/30 │ Recon Loss: 0.012508
#   Epoch  20/30 │ Recon Loss: 0.012046
#   Epoch  25/30 │ Recon Loss: 0.011657
#   Epoch  30/30 │ Recon Loss: 0.011288
# Foundation model pre-training complete.

# %% [markdown]
# ---
# ## 5. Activity & ADMET Scoring Pipeline
# Toxicity prediction using Tox21 + ClinTox data. This feeds into the training pipeline for downstream molecule optimization.

# %%
# ─── Build Tox21 Graph Dataset ───

TOX_ENDPOINTS = [
    'androgen_receptor', 'androgen_receptor_lbd', 'aryl_hydrocarbon_receptor',
    'aromatase', 'estrogen_receptor', 'estrogen_receptor_lbd', 'ppar_gamma',
    'antioxidant_response', 'dna_damage', 'heat_shock',
    'mitochondrial_membrane', 'tumor_suppressor_p53'
]

def build_tox_graph_dataset(df, smiles_col, label_col, max_samples=5000):
    """Build graph dataset for toxicity prediction."""
    graphs = []
    df_sample = df.dropna(subset=[smiles_col, label_col]).head(max_samples)
    for _, row in tqdm(df_sample.iterrows(), total=len(df_sample), desc='Building tox graphs'):
        g = smiles_to_graph(row[smiles_col], y=float(row[label_col]))
        if g is not None:
            graphs.append(g)
    return graphs


# Build Tox21 dataset (binary: is_toxic)
tox21_graphs = build_tox_graph_dataset(tox21, 'drug_smiles', 'is_toxic', max_samples=5000)
print(f'Tox21 graphs built: {len(tox21_graphs)}')

# Train/val/test split
train_graphs, test_graphs = train_test_split(tox21_graphs, test_size=0.2, random_state=42)
train_graphs, val_graphs = train_test_split(train_graphs, test_size=0.15, random_state=42)

print(f'Train: {len(train_graphs)}, Val: {len(val_graphs)}, Test: {len(test_graphs)}')

tox_train_loader = PyGDataLoader(train_graphs, batch_size=64, shuffle=True)
tox_val_loader = PyGDataLoader(val_graphs, batch_size=64)
tox_test_loader = PyGDataLoader(test_graphs, batch_size=64)
# Out:
# Building tox graphs:   0%|          | 0/5000 [00:00<?, ?it/s]
# [16:53:42] WARNING: not removing hydrogen atom without neighbors
# [16:53:44] Explicit valence for atom # 8 Al, 6, is greater than permitted
# [16:53:44] Explicit valence for atom # 3 Al, 6, is greater than permitted
# [16:53:45] Explicit valence for atom # 4 Al, 6, is greater than permitted
# [16:53:46] Explicit valence for atom # 4 Al, 6, is greater than permitted
# [16:53:47] Explicit valence for atom # 9 Al, 6, is greater than permitted
# [16:53:47] Explicit valence for atom # 5 Al, 6, is greater than permitted
# Tox21 graphs built: 4994
# Train: 3395, Val: 600, Test: 999

# %%
# ─── ClinTox Dataset ───

clintox_graphs = build_tox_graph_dataset(clintox, 'smiles', 'CT_TOX', max_samples=1484)
print(f'ClinTox graphs built: {len(clintox_graphs)}')

clintox_train, clintox_test = train_test_split(clintox_graphs, test_size=0.2, random_state=42)
clintox_train_loader = PyGDataLoader(clintox_train, batch_size=64, shuffle=True)
clintox_test_loader = PyGDataLoader(clintox_test, batch_size=64)
# Out:
# Building tox graphs:   0%|          | 0/1484 [00:00<?, ?it/s]
# [16:53:47] Explicit valence for atom # 0 N, 4, is greater than permitted
# [16:53:48] Can't kekulize mol.  Unkekulized atoms: 9
# [16:53:49] Can't kekulize mol.  Unkekulized atoms: 4
# [16:53:49] Can't kekulize mol.  Unkekulized atoms: 4
# ClinTox graphs built: 1480

# %% [markdown]
# ---
# ## 6. Core Neural Architectures
# GNN backbone shared by the Diffusion and Equivariant paths.

# %%
# ─── Core GNN Backbone ───

class CoreGNNBackbone(nn.Module):
    """Shared GNN backbone that processes molecular graphs.
    Outputs node embeddings and a graph-level embedding."""

    def __init__(self, node_feat_dim, hidden_dim=256, num_layers=4, dropout=0.2):
        super().__init__()
        self.input_proj = nn.Linear(node_feat_dim, hidden_dim)

        self.convs = nn.ModuleList()
        self.bns = nn.ModuleList()
        for _ in range(num_layers):
            self.convs.append(GCNConv(hidden_dim, hidden_dim))
            self.bns.append(nn.BatchNorm1d(hidden_dim))

        self.dropout = dropout

    def forward(self, x, edge_index, batch=None):
        x = self.input_proj(x)
        for conv, bn in zip(self.convs, self.bns):
            x_res = x
            x = conv(x, edge_index)
            x = bn(x)
            x = F.relu(x)
            x = F.dropout(x, p=self.dropout, training=self.training)
            x = x + x_res  # residual connection

        # Graph-level readout
        if batch is not None:
            graph_emb = global_mean_pool(x, batch)
        else:
            graph_emb = x.mean(dim=0, keepdim=True)

        return x, graph_emb  # node embeddings, graph embedding


NODE_FEAT_DIM = tox21_graphs[0].x.shape[1]
print(f'Node feature dimension: {NODE_FEAT_DIM}')
# Out:
# Node feature dimension: 146

# %% [markdown]
# ---
# ## 7. Model Engines
#
# ### 7a. Diffusion Path → Graph Diffusion Engine (DiffRM)
# Denoising diffusion model on molecular graphs for **de novo molecule generation**.

# %%
# ─── Graph Diffusion Engine (DiffRM) ───

class GraphDiffusionEngine(nn.Module):
    """Simplified graph diffusion model for molecular generation.
    Learns to denoise molecular graph embeddings via a diffusion process."""

    def __init__(self, node_feat_dim, hidden_dim=256, latent_dim=128, num_steps=100):
        super().__init__()
        self.num_steps = num_steps
        self.latent_dim = latent_dim

        # GNN encoder
        self.backbone = CoreGNNBackbone(node_feat_dim, hidden_dim)

        # Project graph embedding to latent space
        self.proj = nn.Linear(hidden_dim, latent_dim)

        # Time embedding
        self.time_embed = nn.Sequential(
            nn.Linear(1, 64),
            nn.SiLU(),
            nn.Linear(64, latent_dim)
        )

        # Noise prediction network
        self.noise_pred = nn.Sequential(
            nn.Linear(latent_dim * 2, hidden_dim),
            nn.SiLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.SiLU(),
            nn.Linear(hidden_dim, latent_dim)
        )

        # Noise schedule (linear beta schedule)
        betas = torch.linspace(1e-4, 0.02, num_steps)
        alphas = 1.0 - betas
        alpha_bar = torch.cumprod(alphas, dim=0)
        self.register_buffer('betas', betas)
        self.register_buffer('alphas', alphas)
        self.register_buffer('alpha_bar', alpha_bar)

    def encode_graph(self, data):
        """Encode a molecular graph batch to latent vectors."""
        _, graph_emb = self.backbone(data.x, data.edge_index, data.batch)
        return self.proj(graph_emb)

    def forward_diffusion(self, z0, t):
        """Add noise to latent z0 at timestep t."""
        noise = torch.randn_like(z0)
        alpha_bar_t = self.alpha_bar[t].unsqueeze(-1)
        zt = torch.sqrt(alpha_bar_t) * z0 + torch.sqrt(1 - alpha_bar_t) * noise
        return zt, noise

    def predict_noise(self, zt, t):
        """Predict the noise added at timestep t."""
        t_emb = self.time_embed(t.float().unsqueeze(-1) / self.num_steps)
        combined = torch.cat([zt, t_emb], dim=-1)
        return self.noise_pred(combined)

    def training_loss(self, data):
        """Compute diffusion training loss."""
        z0 = self.encode_graph(data)
        t = torch.randint(0, self.num_steps, (z0.size(0),), device=z0.device)
        zt, noise = self.forward_diffusion(z0, t)
        noise_pred = self.predict_noise(zt, t)
        return F.mse_loss(noise_pred, noise)

    @torch.no_grad()
    def sample(self, num_samples=10):
        """Generate new molecular latent vectors via reverse diffusion."""
        self.eval()
        z = torch.randn(num_samples, self.latent_dim, device=next(self.parameters()).device)
        for t_idx in reversed(range(self.num_steps)):
            t = torch.full((num_samples,), t_idx, device=z.device, dtype=torch.long)
            noise_pred = self.predict_noise(z, t)
            alpha_t = self.alphas[t_idx]
            alpha_bar_t = self.alpha_bar[t_idx]
            z = (1 / torch.sqrt(alpha_t)) * (
                z - (self.betas[t_idx] / torch.sqrt(1 - alpha_bar_t)) * noise_pred
            )
            if t_idx > 0:
                z += torch.sqrt(self.betas[t_idx]) * torch.randn_like(z)
        return z  # denoised latent vectors


diffusion_engine = GraphDiffusionEngine(NODE_FEAT_DIM).to(DEVICE)
print(f'Diffusion Engine parameters: {sum(p.numel() for p in diffusion_engine.parameters()):,}')
# Out:
# Diffusion Engine parameters: 508,672

# %% [markdown]
# ### 7b. Equivariant Path → Equivariant Graph Neural Network (EGNN)
# E(n)-equivariant GNN with attention mechanisms for **binding affinity prediction**.

# %%
# ─── Equivariant Graph Neural Network Layer ───

class EGNNLayer(nn.Module):
    """E(n) Equivariant Graph Neural Network layer.
    Updates node features using message passing with coordinate equivariance."""

    def __init__(self, hidden_dim, edge_feat_dim=0):
        super().__init__()
        # Message MLP
        self.msg_mlp = nn.Sequential(
            nn.Linear(hidden_dim * 2 + 1 + edge_feat_dim, hidden_dim),
            nn.SiLU(),
            nn.Linear(hidden_dim, hidden_dim)
        )
        # Node update MLP
        self.node_mlp = nn.Sequential(
            nn.Linear(hidden_dim * 2, hidden_dim),
            nn.SiLU(),
            nn.Linear(hidden_dim, hidden_dim)
        )
        # Attention
        self.attention = nn.Sequential(
            nn.Linear(hidden_dim, 1),
            nn.Sigmoid()
        )

    def forward(self, h, edge_index, edge_attr=None):
        row, col = edge_index
        # Distance feature (using feature-space distance as proxy for coordinates)
        dist = torch.sum((h[row] - h[col]) ** 2, dim=-1, keepdim=True)

        # Build message input
        msg_input = torch.cat([h[row], h[col], dist], dim=-1)
        if edge_attr is not None:
            msg_input = torch.cat([msg_input, edge_attr], dim=-1)

        msg = self.msg_mlp(msg_input)
        attn = self.attention(msg)
        msg = msg * attn  # attention-weighted messages

        # Aggregate messages
        agg = torch.zeros_like(h)
        agg.index_add_(0, col, msg)

        # Update nodes
        h_new = self.node_mlp(torch.cat([h, agg], dim=-1))
        return h + h_new  # residual


class EquivariantGNN(nn.Module):
    """Full Equivariant GNN for binding affinity prediction."""

    def __init__(self, node_feat_dim, hidden_dim=256, num_layers=4, dropout=0.2):
        super().__init__()
        self.input_proj = nn.Linear(node_feat_dim, hidden_dim)
        self.layers = nn.ModuleList([
            EGNNLayer(hidden_dim) for _ in range(num_layers)
        ])
        self.layer_norms = nn.ModuleList([
            nn.LayerNorm(hidden_dim) for _ in range(num_layers)
        ])

        self.predictor = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim // 2),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim // 2, 1)  # binding affinity
        )
        self.dropout = dropout

    def forward(self, x, edge_index, batch):
        h = self.input_proj(x)

        for layer, ln in zip(self.layers, self.layer_norms):
            h = layer(h, edge_index)
            h = ln(h)
            h = F.dropout(h, p=self.dropout, training=self.training)

        # Graph-level readout via attention pooling
        graph_emb = global_mean_pool(h, batch)
        return self.predictor(graph_emb)


egnn_model = EquivariantGNN(NODE_FEAT_DIM).to(DEVICE)
print(f'EGNN parameters: {sum(p.numel() for p in egnn_model.parameters()):,}')
# Out:
# EGNN parameters: 1,651,717

# %% [markdown]
# ---
# ## 8. De Novo SMILES Generation (Diffusion Path Output)
# A SMILES decoder that maps diffusion latent vectors to valid molecular SMILES strings.

# %%
# ─── SMILES Tokenizer ───

import re

SMILES_CHARS = [
    '<pad>', '<sos>', '<eos>',
    'C', 'c', 'N', 'n', 'O', 'o', 'S', 's', 'F', 'I',
    'Cl', 'Br', 'P', 'B', 'Si',
    '(', ')', '[', ']', '=', '#', '+', '-',
    '1', '2', '3', '4', '5', '6', '7', '8', '9',
    '@', '.', '/', '\\', '%', ':', 'H'
]

CHAR2IDX = {c: i for i, c in enumerate(SMILES_CHARS)}
IDX2CHAR = {i: c for c, i in CHAR2IDX.items()}
VOCAB_SIZE = len(SMILES_CHARS)

SMILES_REGEX = re.compile(r'Cl|Br|Si|@@?|\[.*?\]|%\d{2}|.')

def tokenize_smiles(smiles, max_len=120):
    tokens = [CHAR2IDX.get('<sos>')]
    for token in SMILES_REGEX.findall(smiles):
        if token in CHAR2IDX:
            tokens.append(CHAR2IDX[token])
        else:
            for ch in token:
                tokens.append(CHAR2IDX.get(ch, CHAR2IDX['<pad>']))
    tokens.append(CHAR2IDX.get('<eos>'))
    # Pad/truncate
    if len(tokens) > max_len:
        tokens = tokens[:max_len]
    else:
        tokens += [CHAR2IDX['<pad>']] * (max_len - len(tokens))
    return tokens


def decode_tokens(token_ids):
    smiles = ''
    for t in token_ids:
        ch = IDX2CHAR.get(t, '')
        if ch == '<eos>':
            break
        if ch not in ('<pad>', '<sos>'):
            smiles += ch
    return smiles


print(f'SMILES vocabulary size: {VOCAB_SIZE}')
print(f'Tokenized "CCO": {tokenize_smiles("CCO", max_len=10)}')
print(f'Decoded back: "{decode_tokens(tokenize_smiles("CCO", max_len=10))}"')
# Out:
# SMILES vocabulary size: 42
# Tokenized "CCO": [1, 3, 3, 7, 2, 0, 0, 0, 0, 0]
# Decoded back: "CCO"

# %%
# ─── Latent-to-SMILES Decoder ───

class SMILESDecoder(nn.Module):
    """Autoregressive SMILES decoder from latent vectors."""

    def __init__(self, latent_dim=128, hidden_dim=512, vocab_size=VOCAB_SIZE, max_len=120):
        super().__init__()
        self.max_len = max_len
        self.vocab_size = vocab_size
        self.embedding = nn.Embedding(vocab_size, hidden_dim)
        self.latent_proj = nn.Linear(latent_dim, hidden_dim)
        self.gru = nn.GRU(hidden_dim, hidden_dim, num_layers=2, batch_first=True, dropout=0.2)
        self.output_proj = nn.Linear(hidden_dim, vocab_size)

    def forward(self, z, target_tokens=None, teacher_forcing_ratio=0.5):
        """Decode latent vector z to SMILES token sequence."""
        batch_size = z.size(0)
        h = self.latent_proj(z).unsqueeze(0).repeat(2, 1, 1)  # GRU hidden state

        # Start with <sos>
        input_token = torch.full((batch_size, 1), CHAR2IDX['<sos>'],
                                 dtype=torch.long, device=z.device)
        outputs = []

        for t in range(self.max_len):
            emb = self.embedding(input_token)
            out, h = self.gru(emb, h)
            logits = self.output_proj(out)
            outputs.append(logits)

            if target_tokens is not None and np.random.random() < teacher_forcing_ratio:
                input_token = target_tokens[:, t:t+1]
            else:
                input_token = logits.argmax(dim=-1)

        return torch.cat(outputs, dim=1)  # (batch, max_len, vocab_size)

    @torch.no_grad()
    def generate(self, z, temperature=0.8):
        """Generate SMILES from latent vectors with temperature sampling."""
        self.eval()
        batch_size = z.size(0)
        h = self.latent_proj(z).unsqueeze(0).repeat(2, 1, 1)
        input_token = torch.full((batch_size, 1), CHAR2IDX['<sos>'],
                                 dtype=torch.long, device=z.device)
        generated = []

        for _ in range(self.max_len):
            emb = self.embedding(input_token)
            out, h = self.gru(emb, h)
            logits = self.output_proj(out[:, -1, :]) / temperature
            probs = F.softmax(logits, dim=-1)
            next_token = torch.multinomial(probs, 1)
            generated.append(next_token)
            input_token = next_token

        generated = torch.cat(generated, dim=1)
        smiles_list = [decode_tokens(seq.cpu().numpy()) for seq in generated]
        return smiles_list


smiles_decoder = SMILESDecoder(latent_dim=128).to(DEVICE)
print(f'SMILES Decoder parameters: {sum(p.numel() for p in smiles_decoder.parameters()):,}')
# Out:
# SMILES Decoder parameters: 3,260,970

# %% [markdown]
# ---
# ## 9. Binding Affinity Predictor (Equivariant Path Output)
# Predicts drug-protein binding affinity using EGNN with attention mechanisms.

# %%
# ─── Build Binding Affinity Dataset ───

def build_affinity_dataset(df):
    """Build graph dataset for binding affinity prediction."""
    graphs = []
    for _, row in df.iterrows():
        g = smiles_to_graph(row['drug_smiles'], y=float(row['binding_affinity']))
        if g is not None:
            g.drug_name = row['drug_name']
            g.protein_name = row['protein_name']
            g.diagnosis = row['diagnosis']
            graphs.append(g)
    return graphs


affinity_graphs = build_affinity_dataset(drug_protein)
print(f'Binding affinity graphs: {len(affinity_graphs)}')

aff_train, aff_test = train_test_split(affinity_graphs, test_size=0.2, random_state=42)
aff_train_loader = PyGDataLoader(aff_train, batch_size=16, shuffle=True)
aff_test_loader = PyGDataLoader(aff_test, batch_size=16)
# Out:
# Binding affinity graphs: 96
# [16:53:49] Can't kekulize mol.  Unkekulized atoms: 1 2 3 4 8 10
# [16:53:49] Explicit valence for atom # 25 O, 3, is greater than permitted
# [16:53:49] SMILES Parse Error: unclosed ring for input: 'OC(=O)C1CC(Cc2ccc(Cl)cc2)NC(=O)c3nccs3'

# %% [markdown]
# ---
# ## 10. PyTorch & PyG Training Pipeline
# Unified training loop for all model components.

# %%
# ─── Toxicity Classifier (ADMET Scoring) ───

class ToxicityClassifier(nn.Module):
    """GNN-based toxicity classifier using the core backbone."""

    def __init__(self, node_feat_dim, hidden_dim=256, num_layers=4):
        super().__init__()
        self.backbone = CoreGNNBackbone(node_feat_dim, hidden_dim, num_layers)
        self.classifier = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim // 2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden_dim // 2, 1)
        )

    def forward(self, data):
        _, graph_emb = self.backbone(data.x, data.edge_index, data.batch)
        return self.classifier(graph_emb)


tox_model = ToxicityClassifier(NODE_FEAT_DIM).to(DEVICE)
print(f'Toxicity Classifier parameters: {sum(p.numel() for p in tox_model.parameters()):,}')
# Out:
# Toxicity Classifier parameters: 335,873

# %%
# ─── Train Toxicity Classifier (Tox21) ───

tox_optimizer = torch.optim.Adam(tox_model.parameters(), lr=1e-3, weight_decay=1e-5)
tox_scheduler = CosineAnnealingLR(tox_optimizer, T_max=30)
bce_loss = nn.BCEWithLogitsLoss()

TOX_EPOCHS = 30
best_val_auc = 0
train_losses, val_aucs = [], []

for epoch in range(1, TOX_EPOCHS + 1):
    # Train
    tox_model.train()
    total_loss = 0
    for batch in tox_train_loader:
        batch = batch.to(DEVICE)
        logits = tox_model(batch).squeeze(-1)
        loss = bce_loss(logits, batch.y.squeeze(-1))
        tox_optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(tox_model.parameters(), 1.0)
        tox_optimizer.step()
        total_loss += loss.item() * batch.num_graphs
    tox_scheduler.step()
    train_losses.append(total_loss / len(train_graphs))

    # Validate
    tox_model.eval()
    preds, labels = [], []
    with torch.no_grad():
        for batch in tox_val_loader:
            batch = batch.to(DEVICE)
            logits = tox_model(batch).squeeze(-1)
            preds.append(torch.sigmoid(logits).cpu())
            labels.append(batch.y.squeeze(-1).cpu())
    preds = torch.cat(preds).numpy()
    labels = torch.cat(labels).numpy()
    auc = roc_auc_score(labels, preds)
    val_aucs.append(auc)

    if auc > best_val_auc:
        best_val_auc = auc
        torch.save(tox_model.state_dict(), 'best_tox_model.pt')

    if epoch % 5 == 0:
        print(f'  Epoch {epoch:3d}/{TOX_EPOCHS} │ Loss: {train_losses[-1]:.4f} │ Val AUC: {auc:.4f}')

print(f'\nBest Validation AUC: {best_val_auc:.4f}')
# Out:
#   Epoch   5/30 │ Loss: 0.5818 │ Val AUC: 0.7310
#   Epoch  10/30 │ Loss: 0.5543 │ Val AUC: 0.7435
#   Epoch  15/30 │ Loss: 0.5295 │ Val AUC: 0.7466
#   Epoch  20/30 │ Loss: 0.5074 │ Val AUC: 0.7460
#   Epoch  25/30 │ Loss: 0.4943 │ Val AUC: 0.7572
#   Epoch  30/30 │ Loss: 0.4837 │ Val AUC: 0.7574
#
# Best Validation AUC: 0.7598

# %%
# ─── Evaluate Toxicity Classifier on Test Set ───

tox_model.load_state_dict(torch.load('best_tox_model.pt', weights_only=True))
tox_model.eval()

test_preds, test_labels = [], []
with torch.no_grad():
    for batch in tox_test_loader:
        batch = batch.to(DEVICE)
        logits = tox_model(batch).squeeze(-1)
        test_preds.append(torch.sigmoid(logits).cpu())
        test_labels.append(batch.y.squeeze(-1).cpu())

test_preds = torch.cat(test_preds).numpy()
test_labels = torch.cat(test_labels).numpy()

test_auc = roc_auc_score(test_labels, test_preds)
test_acc = accuracy_score(test_labels, (test_preds > 0.5).astype(int))
print(f'Test AUC: {test_auc:.4f}')
print(f'Test Accuracy: {test_acc:.4f}')
print()
print(classification_report(test_labels, (test_preds > 0.5).astype(int),
                            target_names=['Non-toxic', 'Toxic']))

# Plot training curves
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
ax1.plot(train_losses, color='red', label='Train Loss')
ax1.set_xlabel('Epoch'); ax1.set_ylabel('Loss')
ax1.set_title('Toxicity Model Training Loss'); ax1.legend(); ax1.grid(True, alpha=0.3)

ax2.plot(val_aucs, color='blue', label='Val AUC')
ax2.axhline(y=test_auc, color='green', linestyle='--', label=f'Test AUC={test_auc:.4f}')
ax2.set_xlabel('Epoch'); ax2.set_ylabel('AUC')
ax2.set_title('Toxicity Model Validation AUC'); ax2.legend(); ax2.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Test AUC: 0.7818
# Test Accuracy: 0.7518
#
#               precision    recall  f1-score   support
#
#    Non-toxic       0.79      0.85      0.82       653
#        Toxic       0.67      0.57      0.61       346
#
#     accuracy                           0.75       999
#    macro avg       0.73      0.71      0.71       999
# weighted avg       0.75      0.75      0.75       999

# %%
# ─── Train Diffusion Engine (Graph Diffusion for Molecule Generation) ───

diff_optimizer = torch.optim.Adam(diffusion_engine.parameters(), lr=5e-4)
diff_scheduler = CosineAnnealingLR(diff_optimizer, T_max=50)

# Use tox21 non-toxic molecules for training generation model
nontoxic_smiles = tox21[tox21['is_toxic'] == 0]['drug_smiles'].tolist()
gen_graphs = []
for smi in tqdm(nontoxic_smiles[:3000], desc='Building generation graphs'):
    g = smiles_to_graph(smi)
    if g is not None:
        gen_graphs.append(g)

gen_loader = PyGDataLoader(gen_graphs, batch_size=64, shuffle=True)
print(f'Generation training graphs: {len(gen_graphs)}')

DIFF_EPOCHS = 50
diff_losses = []

for epoch in range(1, DIFF_EPOCHS + 1):
    diffusion_engine.train()
    total_loss = 0
    for batch in gen_loader:
        batch = batch.to(DEVICE)
        loss = diffusion_engine.training_loss(batch)
        diff_optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(diffusion_engine.parameters(), 1.0)
        diff_optimizer.step()
        total_loss += loss.item() * batch.num_graphs
    diff_scheduler.step()
    diff_losses.append(total_loss / len(gen_graphs))

    if epoch % 10 == 0:
        print(f'  Epoch {epoch:3d}/{DIFF_EPOCHS} │ Diffusion Loss: {diff_losses[-1]:.6f}')

plt.figure(figsize=(8, 4))
plt.plot(diff_losses, color='purple')
plt.xlabel('Epoch'); plt.ylabel('Diffusion Loss')
plt.title('Graph Diffusion Engine Training')
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# Building generation graphs:   0%|          | 0/3000 [00:00<?, ?it/s]
# [16:54:13] WARNING: not removing hydrogen atom without neighbors
# [16:54:14] Explicit valence for atom # 8 Al, 6, is greater than permitted
# [16:54:15] Explicit valence for atom # 3 Al, 6, is greater than permitted
# [16:54:15] Explicit valence for atom # 4 Al, 6, is greater than permitted
# [16:54:16] Explicit valence for atom # 9 Al, 6, is greater than permitted
# [16:54:16] Explicit valence for atom # 5 Al, 6, is greater than permitted
# Generation training graphs: 2995
#   Epoch  10/50 │ Diffusion Loss: 0.544330
#   Epoch  20/50 │ Diffusion Loss: 0.390649
#   Epoch  30/50 │ Diffusion Loss: 0.313513
#   Epoch  40/50 │ Diffusion Loss: 0.277242
#   Epoch  50/50 │ Diffusion Loss: 0.270929

# %%
# ─── Train SMILES Decoder (paired with Diffusion Engine) ───

class SMILESDataset(Dataset):
    def __init__(self, smiles_list, max_len=120):
        self.data = []
        for smi in smiles_list:
            tokens = tokenize_smiles(smi, max_len=max_len)
            self.data.append(torch.tensor(tokens, dtype=torch.long))

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.data[idx]


# Build paired dataset: graphs + SMILES tokens
paired_smiles = [g.smiles for g in gen_graphs[:2000]]
smiles_dataset = SMILESDataset(paired_smiles, max_len=120)
smiles_loader = DataLoader(smiles_dataset, batch_size=64, shuffle=True)

dec_optimizer = torch.optim.Adam(smiles_decoder.parameters(), lr=1e-3)

DEC_EPOCHS = 30
dec_losses = []

for epoch in range(1, DEC_EPOCHS + 1):
    smiles_decoder.train()
    total_loss = 0
    for tokens_batch in smiles_loader:
        tokens_batch = tokens_batch.to(DEVICE)
        # Random latent vectors (later will use diffusion output)
        z = torch.randn(tokens_batch.size(0), 128, device=DEVICE)
        logits = smiles_decoder(z, target_tokens=tokens_batch, teacher_forcing_ratio=0.5)
        loss = F.cross_entropy(
            logits.view(-1, VOCAB_SIZE),
            tokens_batch.view(-1),
            ignore_index=CHAR2IDX['<pad>']
        )
        dec_optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(smiles_decoder.parameters(), 1.0)
        dec_optimizer.step()
        total_loss += loss.item() * tokens_batch.size(0)

    dec_losses.append(total_loss / len(smiles_dataset))
    if epoch % 5 == 0:
        print(f'  Epoch {epoch:3d}/{DEC_EPOCHS} │ Decoder Loss: {dec_losses[-1]:.4f}')

plt.figure(figsize=(8, 4))
plt.plot(dec_losses, color='teal')
plt.xlabel('Epoch'); plt.ylabel('Decoder Loss')
plt.title('SMILES Decoder Training')
plt.grid(True, alpha=0.3)
plt.show()
# Out:
#   Epoch   5/30 │ Decoder Loss: 1.6926
#   Epoch  10/30 │ Decoder Loss: 1.6236
#   Epoch  15/30 │ Decoder Loss: 1.5755
#   Epoch  20/30 │ Decoder Loss: 1.5537
#   Epoch  25/30 │ Decoder Loss: 1.5345
#   Epoch  30/30 │ Decoder Loss: 1.5029

# %%
# ─── Train Binding Affinity Predictor (EGNN) ───

aff_optimizer = torch.optim.Adam(egnn_model.parameters(), lr=1e-3, weight_decay=1e-5)
aff_scheduler = CosineAnnealingLR(aff_optimizer, T_max=50)

AFF_EPOCHS = 50
aff_train_losses, aff_val_losses = [], []

for epoch in range(1, AFF_EPOCHS + 1):
    egnn_model.train()
    total_loss = 0
    n_samples = 0
    for batch in aff_train_loader:
        batch = batch.to(DEVICE)
        pred = egnn_model(batch.x, batch.edge_index, batch.batch).squeeze(-1)
        loss = F.mse_loss(pred, batch.y.squeeze(-1))
        aff_optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(egnn_model.parameters(), 1.0)
        aff_optimizer.step()
        total_loss += loss.item() * batch.num_graphs
        n_samples += batch.num_graphs
    aff_scheduler.step()
    aff_train_losses.append(total_loss / n_samples)

    # Evaluate
    egnn_model.eval()
    val_loss = 0
    n_val = 0
    with torch.no_grad():
        for batch in aff_test_loader:
            batch = batch.to(DEVICE)
            pred = egnn_model(batch.x, batch.edge_index, batch.batch).squeeze(-1)
            val_loss += F.mse_loss(pred, batch.y.squeeze(-1)).item() * batch.num_graphs
            n_val += batch.num_graphs
    aff_val_losses.append(val_loss / n_val)

    if epoch % 10 == 0:
        print(f'  Epoch {epoch:3d}/{AFF_EPOCHS} │ Train MSE: {aff_train_losses[-1]:.4f} │ Val MSE: {aff_val_losses[-1]:.4f}')

# Plot
plt.figure(figsize=(8, 4))
plt.plot(aff_train_losses, label='Train MSE', color='navy')
plt.plot(aff_val_losses, label='Val MSE', color='orange')
plt.xlabel('Epoch'); plt.ylabel('MSE Loss')
plt.title('Binding Affinity Predictor (EGNN) Training')
plt.legend(); plt.grid(True, alpha=0.3)
plt.show()
# Out:
#   Epoch  10/50 │ Train MSE: 1.2641 │ Val MSE: 0.7193
#   Epoch  20/50 │ Train MSE: 1.1346 │ Val MSE: 0.8619
#   Epoch  30/50 │ Train MSE: 0.8444 │ Val MSE: 0.7272
#   Epoch  40/50 │ Train MSE: 0.9987 │ Val MSE: 0.7286
#   Epoch  50/50 │ Train MSE: 0.8658 │ Val MSE: 0.7143

# %%
# ─── Evaluate Binding Affinity Predictor ───

egnn_model.eval()
all_preds, all_labels = [], []
drug_names, protein_names, diagnoses = [], [], []

with torch.no_grad():
    for batch in aff_test_loader:
        batch = batch.to(DEVICE)
        pred = egnn_model(batch.x, batch.edge_index, batch.batch).squeeze(-1)
        all_preds.append(pred.cpu())
        all_labels.append(batch.y.squeeze(-1).cpu())

all_preds = torch.cat(all_preds).numpy()
all_labels = torch.cat(all_labels).numpy()

rmse = np.sqrt(mean_squared_error(all_labels, all_preds))
r2 = r2_score(all_labels, all_preds)
print(f'Binding Affinity Prediction — RMSE: {rmse:.4f}, R²: {r2:.4f}')

plt.figure(figsize=(6, 6))
plt.scatter(all_labels, all_preds, alpha=0.6, edgecolors='black', linewidths=0.5)
mn, mx = min(all_labels.min(), all_preds.min()) - 0.5, max(all_labels.max(), all_preds.max()) + 0.5
plt.plot([mn, mx], [mn, mx], 'r--', linewidth=1.5)
plt.xlabel('True Binding Affinity')
plt.ylabel('Predicted Binding Affinity')
plt.title(f'Binding Affinity: Predicted vs True (R²={r2:.3f})')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Binding Affinity Prediction — RMSE: 0.8452, R²: 0.0065

# %% [markdown]
# ---
# ## 11. De Novo SMILES Generation (Diffusion → Decoder)
# Generate novel molecules using the trained diffusion engine + SMILES decoder.

# %%
# ─── Generate Novel Molecules ───

NUM_GENERATE = 100

# Sample latent vectors from diffusion engine
diffusion_engine.eval()
latent_vectors = diffusion_engine.sample(num_samples=NUM_GENERATE)

# Decode to SMILES
generated_smiles = smiles_decoder.generate(latent_vectors, temperature=0.8)

# Validate generated SMILES
valid_smiles = []
for smi in generated_smiles:
    mol = Chem.MolFromSmiles(smi)
    if mol is not None:
        valid_smiles.append(Chem.MolToSmiles(mol))  # canonicalize

unique_smiles = list(set(valid_smiles))
validity = len(valid_smiles) / NUM_GENERATE * 100
uniqueness = len(unique_smiles) / max(len(valid_smiles), 1) * 100

print(f'Generated: {NUM_GENERATE} molecules')
print(f'Valid:     {len(valid_smiles)} ({validity:.1f}%)')
print(f'Unique:    {len(unique_smiles)} ({uniqueness:.1f}%)')
print(f'\nSample generated SMILES:')
for smi in unique_smiles[:10]:
    print(f'  {smi}')
# Out:
# Generated: 100 molecules
# Valid:     9 (9.0%)
# Unique:    9 (100.0%)
#
# Sample generated SMILES:
#   CC(Cl)Br
#   CC(=O)O
#   CN([O-])c1ccccc1
#   Cc1ccccc1C
#   CC(Cl)CCl
#   C=C(O)O
#   CCCCc1ccc(CC=O)c2ccccc12
#   CC(CO)CCCl
#   CCC1=CC=C(O)CN=CC=CC=C1
# [16:57:43] SMILES Parse Error: syntax error while parsing: C=CN+]([O-])c1ccc(c1
# [16:57:43] SMILES Parse Error: check for mistakes around position 5:
# [16:57:43] C=CN+]([O-])c1ccc(c1
# [16:57:43] ~~~~^
# [16:57:43] SMILES Parse Error: Failed parsing SMILES 'C=CN+]([O-])c1ccc(c1' for input: 'C=CN+]([O-])c1ccc(c1'
# [16:57:43] SMILES Parse Error: syntax error while parsing: O=CN+]([O-])c1ccc([OH]c2ccccc221
# [16:57:43] SMILES Parse Error: check for mistakes around position 5:
# [16:57:43] O=CN+]([O-])c1ccc([OH]c2ccccc221
# [16:57:43] ~~~~^
# [16:57:43] SMILES Parse Error: Failed parsing SMILES 'O=CN+]([O-])c1ccc([OH]c2ccccc221' for input: 'O=CN+]([O-])c1ccc([OH]c2ccccc221'
# [16:57:43] SMILES Parse Error: syntax error while parsing: CCCC(=O)Nc(C@H]1C[C=O)NC2ccc(sc21)c1c=O)[C@@]3[C@@](OC[[C@]1(C))[C@@](O)[C@H]12CC[C@H](C)Cc=O)[C@@H]1C
# [16:57:43] SMILES Parse Error: check for mistakes around position 13:
# [16:57:43] CCCC(=O)Nc(C@H]1C[C=O)NC2ccc(sc21)c1c=O)[
# [16:57:43] ~~~~~~~~~~~~^
# [16:57:43] SMILES Parse Error: extra open parentheses while parsing: CCCC(=O)Nc(C@H]1C[C=O)NC2ccc(sc21)c1c=O)[C@@]3[C@@](OC[[C@]1(C))[C@@](O)[C@H]12CC[C@H](C)Cc=O)[C@@H]1C
# [16:57:43] SMILES Parse Error: check for mistakes around position 11:
# [16:57:43] CCCC(=O)Nc(C@H]1C[C=O)NC2ccc(sc21)c1c=O)[
# [16:57:43] ~~~~~~~~~~^
# [16:57:43] SMILES Parse Error: Failed parsing SMILES 'CCCC(=O)Nc(C@H]1C[C=O)NC2ccc(sc21)c1c=O)[C@@]3[C@@](OC[[C@]1(C))[C@@](O)[C@H]12CC[C@H](C)Cc=O)[C@@H]1C' for input: 'CCCC(=O)Nc(C@H]1C[C=O)NC2ccc(sc21)c1c=O)[C@@]3[C@@](OC[[C@]1(C))[C@@](O)[C@H]12CC[C@H](C)Cc=O)[C@@H]1C'
# [16:57:43] SMILES Parse Error: extra close parentheses while parsing: C[C@@]1(NC(CCC1cCO)C1CC(Cc2ccccc2)=C(O)C3)CC2)cc1
# [16:57:43] SMILES Parse Error: check for mistakes around position 46:
# [16:57:43] c2ccccc2)=C(O)C3)CC2)cc1
# [16:57:43] ~~~~~~~~~~~~~~~~~~~~^
# [16:57:43] SMILES Parse Error: Failed parsing SMILES 'C[C@@]1(NC(CCC1cCO)C1CC(Cc2ccccc2)=C(O)C3)CC2)cc1' for input: 'C[C@@]1(NC(CCC1cCO)C1CC(Cc2ccccc2)=C(O)C3)CC2)cc1'
# [16:57:43] SMILES Parse Error: extra close parentheses while parsing: O=C1CN2CCCCC1ccccF)cc2cc3cc3cC2ccc(Fc2F)1
# [16:57:43] SMILES Parse Error: check for mistakes around position 19:
# [16:57:43] O=C1CN2CCCCC1ccccF)cc2cc3cc3cC2ccc(Fc2F)1
# [16:57:43] ~~~~~~~~~~~~~~~~~~^
# [16:57:43] SMILES Parse Error: Failed parsing SMILES 'O=C1CN2CCCCC1ccccF)cc2cc3cc3cC2ccc(Fc2F)1' for input: 'O=C1CN2CCCCC1ccccF)cc2cc3cc3cC2ccc(Fc2F)1'
# [16:57:43] SMILES Parse Error: unclosed ring for input: 'Cc1cc(-c2occ1ccccCl)1'
# [16:57:43] SMILES Parse Error: extra close parentheses while parsing: CCCCCCCCCC[n+]1ccc(F)FF)F)cc1F
# [16:57:43] SMILES Parse Error: check for mistakes around position 24:
# [16:57:43] CCCCCCC[n+]1ccc(F)FF)F)cc1F
# [16:57:43] ~~~~~~~~~~~~~~~~~~~~^
# [16:57:43] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCC[n+]1ccc(F)FF)F)cc1F' for input: 'CCCCCCCCCC[n+]1ccc(F)FF)F)cc1F'
# [16:57:43] SMILES Parse Error: extra close parentheses while parsing: CN(C)O)[C@@H]1C[C@H](CO)O[@@H](OCc2ccc(O))cc2)CC(=O)[(@](CCC1ccc(ON+](=O)[O-])cc3)c(=O)[O-])c(CC)cc2()c=O)[O-])c2
# [16:57:43] SMILES Parse Error: check for mistakes around position 7:
# [16:57:43] CN(C)O)[C@@H]1C[C@H](CO)O[@@H](OCc2ccc(O)
# [16:57:43] ~~~~~~^
# [16:57:43] SMILES Parse Error: Failed parsing SMILES 'CN(C)O)[C@@H]1C[C@H](CO)O[@@H](OCc2ccc(O))cc2)CC(=O)[(@](CCC1ccc(ON+](=O)[O-])cc3)c(=O)[O-])c(CC)cc2()c=O)[O-])c2' for input: 'CN(C)O)[C@@H]1C[C@H](CO)O[@@H](OCc2ccc(O))cc2)CC(=O)[(@](CCC1ccc(ON+](=O)[O-])cc3)c(=O)[O-])c(CC)cc2()c=O)[O-])c2'
# [16:57:43] SMILES Parse Error: syntax error while parsing: CC1ccc(CN+](=O)[O-])c1CCO
# [16:57:43] SMILES Parse Error: check for mistakes around position 10:
# [16:57:43] CC1ccc(CN+](=O)[O-])c1CCO
# [16:57:43] ~~~~~~~~~^
# [16:57:43] SMILES Parse Error: extra open parentheses while parsing: CC1ccc(CN+](=O)[O-])c1CCO
# [16:57:43] SMILES Parse Error: check for mistakes around position 7:
# [16:57:43] CC1ccc(CN+](=O)[O-])c1CCO
# [16:57:43] ~~~~~~^
# [16:57:43] SMILES Parse Error: Failed parsing SMILES 'CC1ccc(CN+](=O)[O-])c1CCO' for input: 'CC1ccc(CN+](=O)[O-])c1CCO'
# [16:57:43] SMILES Parse Error: syntax error while parsing: C=C((N[C@@H](C)[C(O)CC(=O)O
# [16:57:43] SMILES Parse Error: check for mistakes around position 5:
# [16:57:43] C=C((N[C@@H](C)[C(O)CC(=O)O
# [16:57:43] ~~~~^
# [16:57:43] SMILES Parse Error: Failed parsing SMILES 'C=C((N[C@@H](C)[C(O)CC(=O)O' for input: 'C=C((N[C@@H](C)[C(O)CC(=O)O'
# [16:57:43] SMILES Parse Error: syntax error while parsing: CC=CN@@H](NC(=O)cC)OCC=O)O
# [16:57:43] SMILES Parse Error: check for mistakes around position 6:
# [16:57:43] CC=CN@@H](NC(=O)cC)OCC=O)O
# [16:57:43] ~~~~~^
# [16:57:43] SMILES Parse Error: Failed parsing SMILES 'CC=CN@@H](NC(=O)cC)OCC=O)O' for input: 'CC=CN@@H](NC(=O)cC)OCC=O)O'
# [16:57:43] SMILES Parse Error: extra close parentheses while parsing: CC1cCC=O)C1cc(Cl)cc(Cl)c1
# [16:57:43] SMILES Parse Error: check for mistakes around position 9:
# [16:57:43] CC1cCC=O)C1cc(Cl)cc(Cl)c1
# [16:57:43] ~~~~~~~~^
# [16:57:43] SMILES Parse Error: Failed parsing SMILES 'CC1cCC=O)C1cc(Cl)cc(Cl)c1' for input: 'CC1cCC=O)C1cc(Cl)cc(Cl)c1'
# [16:57:43] SMILES Parse Error: extra open parentheses while parsing: COC(ccccCC(OCC1
# [16:57:43] SMILES Parse Error: check for mistakes around position 4:
# [16:57:43] COC(ccccCC(OCC1
# [16:57:43] ~~~^
# [16:57:43] SMILES Parse Error: extra open parentheses while parsing: COC(ccccCC(OCC1
# [16:57:43] SMILES Parse Error: check for mistakes around position 11:
# [16:57:43] COC(ccccCC(OCC1
# [16:57:43] ~~~~~~~~~~^
# [16:57:43] SMILES Parse Error: Failed parsing SMILES 'COC(ccccCC(OCC1' for input: 'COC(ccccCC(OCC1'
# [16:57:43] SMILES Parse Error: syntax error while parsing: O=C([O-])c1ccc(cOC]((O)c3ccccccc(N)C@H](Cnc]ccc=O)[O-])cn3)[C@](O)[C@]@H](N)CCC(C)F)F)C(=)F)=O)NCcccC[C@@H](Cc1nc[C@H]1
# [16:57:43] SMILES Parse Error: check for mistakes around position 19:
# [16:57:43] O=C([O-])c1ccc(cOC]((O)c3ccccccc(N)C@H](C
# [16:57:43] ~~~~~~~~~~~~~~~~~~^
# [16:57:43] SMILES Parse Error: extra open parentheses while parsing: O=C([O-])c1ccc(cOC]((O)c3ccccccc(N)C@H](Cnc]ccc=O)[O-])cn3)[C@](O)[C@]@H](N)CCC(C)F)F)C(=)F)=O)NCcccC[C@@H](Cc1nc[C@H]1
# [16:57:43] SMILES Parse Error: check for mistakes around position 15:
# [16:57:43] O=C([O-])c1ccc(cOC]((O)c3ccccccc(N)C@H](C
# [16:57:43] ~~~~~~~~~~~~~~^
# [16:57:43] SMILES Parse Error: Failed parsing SMILES 'O=C([O-])c1ccc(cOC]((O)c3ccccccc(N)C@H](Cnc]ccc=O)[O-])cn3)[C@](O)[C@]@H](N)CCC(C)F)F)C(=)F)=O)NCcccC[C@@H](Cc1nc[C@H]1' for input: 'O=C([O-])c1ccc(cOC]((O)c3ccccccc(N)C@H](Cnc]ccc=O)[O-])cn3)[C@](O)[C@]@H](N)CCC(C)F)F)C(=)F)=O)NCcccC[C@@H](Cc1nc[C@H]1'
# [16:57:43] SMILES Parse Error: extra close parentheses while parsing: CCCC(=O)O)c1cCCCCC
# [16:57:43] SMILES Parse Error: check for mistakes around position 10:
# [16:57:43] CCCC(=O)O)c1cCCCCC
# [16:57:43] ~~~~~~~~~^
# [16:57:43] SMILES Parse Error: Failed parsing SMILES 'CCCC(=O)O)c1cCCCCC' for input: 'CCCC(=O)O)c1cCCCCC'
# [16:57:43] SMILES Parse Error: syntax error while parsing: CC1CC(CO)c1ccc((F)F)c2)cc1
# [16:57:43] SMILES Parse Error: check for mistakes around position 16:
# [16:57:43] CC1CC(CO)c1ccc((F)F)c2)cc1
# [16:57:43] ~~~~~~~~~~~~~~~^
# [16:57:43] SMILES Parse Error: Failed parsing SMILES 'CC1CC(CO)c1ccc((F)F)c2)cc1' for input: 'CC1CC(CO)c1ccc((F)F)c2)cc1'
# [16:57:43] SMILES Parse Error: ring closure 1 duplicates bond between atom 23 and atom 24 for input: 'CCCC1Cc(OCNC[C@]2(O)C1cC3CCCC3)[C@@H](C)C(O)[C@@H]1C1'
# [16:57:43] Explicit valence for atom # 2 C, 5, is greater than permitted
# [16:57:44] SMILES Parse Error: extra open parentheses while parsing: CCCCC(CO)c1ccc(c1
# [16:57:44] SMILES Parse Error: check for mistakes around position 15:
# [16:57:44] CCCCC(CO)c1ccc(c1
# [16:57:44] ~~~~~~~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'CCCCC(CO)c1ccc(c1' for input: 'CCCCC(CO)c1ccc(c1'
# [16:57:44] SMILES Parse Error: extra close parentheses while parsing: CCCC(CC)CC=O)NCC(C()Cnc(c12C(=O)O2cCCC[C@H](=O)[C@H]C2)=C1C
# [16:57:44] SMILES Parse Error: check for mistakes around position 13:
# [16:57:44] CCCC(CC)CC=O)NCC(C()Cnc(c12C(=O)O2cCCC[C@
# [16:57:44] ~~~~~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'CCCC(CC)CC=O)NCC(C()Cnc(c12C(=O)O2cCCC[C@H](=O)[C@H]C2)=C1C' for input: 'CCCC(CC)CC=O)NCC(C()Cnc(c12C(=O)O2cCCC[C@H](=O)[C@H]C2)=C1C'
# [16:57:44] SMILES Parse Error: syntax error while parsing: Cc1cc2c(cc2cOCc1cccc(@]]1)[C@H](CC@@](C)CCCN3CCCC[C@@]1C)[C@H]]3CC[C@@]2CO)CC@H]21
# [16:57:44] SMILES Parse Error: check for mistakes around position 22:
# [16:57:44] c1cc2c(cc2cOCc1cccc(@]]1)[C@H](CC@@](C)CC
# [16:57:44] ~~~~~~~~~~~~~~~~~~~~^
# [16:57:44] SMILES Parse Error: extra open parentheses while parsing: Cc1cc2c(cc2cOCc1cccc(@]]1)[C@H](CC@@](C)CCCN3CCCC[C@@]1C)[C@H]]3CC[C@@]2CO)CC@H]21
# [16:57:44] SMILES Parse Error: check for mistakes around position 8:
# [16:57:44] Cc1cc2c(cc2cOCc1cccc(@]]1)[C@H](CC@@](C)C
# [16:57:44] ~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'Cc1cc2c(cc2cOCc1cccc(@]]1)[C@H](CC@@](C)CCCN3CCCC[C@@]1C)[C@H]]3CC[C@@]2CO)CC@H]21' for input: 'Cc1cc2c(cc2cOCc1cccc(@]]1)[C@H](CC@@](C)CCCN3CCCC[C@@]1C)[C@H]]3CC[C@@]2CO)CC@H]21'
# [16:57:44] SMILES Parse Error: extra close parentheses while parsing: CCC=O)O)Nc1ccc()cc1cC(N)=O)C)c1
# [16:57:44] SMILES Parse Error: check for mistakes around position 6:
# [16:57:44] CCC=O)O)Nc1ccc()cc1cC(N)=O)C)c1
# [16:57:44] ~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'CCC=O)O)Nc1ccc()cc1cC(N)=O)C)c1' for input: 'CCC=O)O)Nc1ccc()cc1cC(N)=O)C)c1'
# [16:57:44] SMILES Parse Error: syntax error while parsing: O=C([C@HH](CN2CCN(CC@)c3c3cccccc3)[C@@H](N)CC4cC[C@@](CC(@H]12
# [16:57:44] SMILES Parse Error: check for mistakes around position 9:
# [16:57:44] O=C([C@HH](CN2CCN(CC@)c3c3cccccc3)[C@@H](
# [16:57:44] ~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'O=C([C@HH](CN2CCN(CC@)c3c3cccccc3)[C@@H](N)CC4cC[C@@](CC(@H]12' for input: 'O=C([C@HH](CN2CCN(CC@)c3c3cccccc3)[C@@H](N)CC4cC[C@@](CC(@H]12'
# [16:57:44] SMILES Parse Error: syntax error while parsing: CC(CO)CCCccccC(1
# [16:57:44] SMILES Parse Error: check for mistakes around position 16:
# [16:57:44] CC(CO)CCCccccC(1
# [16:57:44] ~~~~~~~~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'CC(CO)CCCccccC(1' for input: 'CC(CO)CCCccccC(1'
# [16:57:44] SMILES Parse Error: extra close parentheses while parsing: CC(C)CC=O)N(Cc1ccccc1
# [16:57:44] SMILES Parse Error: check for mistakes around position 10:
# [16:57:44] CC(C)CC=O)N(Cc1ccccc1
# [16:57:44] ~~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'CC(C)CC=O)N(Cc1ccccc1' for input: 'CC(C)CC=O)N(Cc1ccccc1'
# [16:57:44] SMILES Parse Error: extra close parentheses while parsing: CCOC(=O)CCc1cc(Cl)co2(C)CCCC)ccc
# [16:57:44] SMILES Parse Error: check for mistakes around position 29:
# [16:57:44] CCc1cc(Cl)co2(C)CCCC)ccc
# [16:57:44] ~~~~~~~~~~~~~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'CCOC(=O)CCc1cc(Cl)co2(C)CCCC)ccc' for input: 'CCOC(=O)CCc1cc(Cl)co2(C)CCCC)ccc'
# [16:57:44] SMILES Parse Error: extra close parentheses while parsing: CCC[N+]1(C)CCCC1ccccc)ccc
# [16:57:44] SMILES Parse Error: check for mistakes around position 22:
# [16:57:44] CC[N+]1(C)CCCC1ccccc)ccc
# [16:57:44] ~~~~~~~~~~~~~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'CCC[N+]1(C)CCCC1ccccc)ccc' for input: 'CCC[N+]1(C)CCCC1ccccc)ccc'
# [16:57:44] SMILES Parse Error: ring closure 1 duplicates bond between atom 7 and atom 8 for input: 'CCCC(C)Ccc1c1CC'
# [16:57:44] SMILES Parse Error: extra close parentheses while parsing: CCCCCCO)[O-].[Nn+]1(C)CC
# [16:57:44] SMILES Parse Error: check for mistakes around position 8:
# [16:57:44] CCCCCCO)[O-].[Nn+]1(C)CC
# [16:57:44] ~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'CCCCCCO)[O-].[Nn+]1(C)CC' for input: 'CCCCCCO)[O-].[Nn+]1(C)CC'
# [16:57:44] Explicit valence for atom # 7 O, 3, is greater than permitted
# [16:57:44] SMILES Parse Error: syntax error while parsing: C[C@]((C)CC@]1(CC(O)CCccccc1ccccccOCCC.O=C([O-])C[C@])(CCC)(C(F)(F)F
# [16:57:44] SMILES Parse Error: check for mistakes around position 7:
# [16:57:44] C[C@]((C)CC@]1(CC(O)CCccccc1ccccccOCCC.O=
# [16:57:44] ~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'C[C@]((C)CC@]1(CC(O)CCccccc1ccccccOCCC.O=C([O-])C[C@])(CCC)(C(F)(F)F' for input: 'C[C@]((C)CC@]1(CC(O)CCccccc1ccccccOCCC.O=C([O-])C[C@])(CCC)(C(F)(F)F'
# [16:57:44] SMILES Parse Error: extra close parentheses while parsing: C=C1Nc2ccccc2[C@@](CC)[C@H](C(=O)N2C(CCO)ccOC)c(C)C))s1
# [16:57:44] SMILES Parse Error: check for mistakes around position 52:
# [16:57:44] O)N2C(CCO)ccOC)c(C)C))s1
# [16:57:44] ~~~~~~~~~~~~~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'C=C1Nc2ccccc2[C@@](CC)[C@H](C(=O)N2C(CCO)ccOC)c(C)C))s1' for input: 'C=C1Nc2ccccc2[C@@](CC)[C@H](C(=O)N2C(CCO)ccOC)c(C)C))s1'
# [16:57:44] Can't kekulize mol.  Unkekulized atoms: 7
# [16:57:44] SMILES Parse Error: syntax error while parsing: COc1ccc((c1cc)CCCCCC1
# [16:57:44] SMILES Parse Error: check for mistakes around position 9:
# [16:57:44] COc1ccc((c1cc)CCCCCC1
# [16:57:44] ~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'COc1ccc((c1cc)CCCCCC1' for input: 'COc1ccc((c1cc)CCCCCC1'
# [16:57:44] SMILES Parse Error: syntax error while parsing: NC1=C(CN2CCCCC2C(N)=O)N[C@@]((C[C@H]4cOC((=O))cC[C+]3CCCCCCC1)c=O)Cc2c(C)cc2))cC1
# [16:57:44] SMILES Parse Error: check for mistakes around position 30:
# [16:57:44] CCCCC2C(N)=O)N[C@@]((C[C@H]4cOC((=O))cC[C
# [16:57:44] ~~~~~~~~~~~~~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'NC1=C(CN2CCCCC2C(N)=O)N[C@@]((C[C@H]4cOC((=O))cC[C+]3CCCCCCC1)c=O)Cc2c(C)cc2))cC1' for input: 'NC1=C(CN2CCCCC2C(N)=O)N[C@@]((C[C@H]4cOC((=O))cC[C+]3CCCCCCC1)c=O)Cc2c(C)cc2))cC1'
# [16:57:44] SMILES Parse Error: extra close parentheses while parsing: CCC=O)NC1cccC)c)cc(Cc1ccccc2)1
# [16:57:44] SMILES Parse Error: check for mistakes around position 6:
# [16:57:44] CCC=O)NC1cccC)c)cc(Cc1ccccc2)1
# [16:57:44] ~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'CCC=O)NC1cccC)c)cc(Cc1ccccc2)1' for input: 'CCC=O)NC1cccC)c)cc(Cc1ccccc2)1'
# [16:57:44] SMILES Parse Error: extra close parentheses while parsing: CN(C)CC1cCC)c[C@@H]2C[C@@H](CCC(O)=C3C[C@H]2C)COCCcc=O)OS(=O)(=O)[C@@](F)c3cccc()O)cc3)CC@NC
# [16:57:44] SMILES Parse Error: check for mistakes around position 12:
# [16:57:44] CN(C)CC1cCC)c[C@@H]2C[C@@H](CCC(O)=C3C[C@
# [16:57:44] ~~~~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'CN(C)CC1cCC)c[C@@H]2C[C@@H](CCC(O)=C3C[C@H]2C)COCCcc=O)OS(=O)(=O)[C@@](F)c3cccc()O)cc3)CC@NC' for input: 'CN(C)CC1cCC)c[C@@H]2C[C@@H](CCC(O)=C3C[C@H]2C)COCCcc=O)OS(=O)(=O)[C@@](F)c3cccc()O)cc3)CC@NC'
# [16:57:44] SMILES Parse Error: syntax error while parsing: Cc1ccc((CCCO)ccO)Nc2nc((CCC2)nc1C
# [16:57:44] SMILES Parse Error: check for mistakes around position 8:
# [16:57:44] Cc1ccc((CCCO)ccO)Nc2nc((CCC2)nc1C
# [16:57:44] ~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'Cc1ccc((CCCO)ccO)Nc2nc((CCC2)nc1C' for input: 'Cc1ccc((CCCO)ccO)Nc2nc((CCC2)nc1C'
# [16:57:44] SMILES Parse Error: syntax error while parsing: CCOC((CC)c1O)c(2=N(C)CC3O)C3)CCcc(Cl)3)n1
# [16:57:44] SMILES Parse Error: check for mistakes around position 6:
# [16:57:44] CCOC((CC)c1O)c(2=N(C)CC3O)C3)CCcc(Cl)3)n1
# [16:57:44] ~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'CCOC((CC)c1O)c(2=N(C)CC3O)C3)CCcc(Cl)3)n1' for input: 'CCOC((CC)c1O)c(2=N(C)CC3O)C3)CCcc(Cl)3)n1'
# [16:57:44] SMILES Parse Error: extra open parentheses while parsing: CC(C)COc1ccc(c1
# [16:57:44] SMILES Parse Error: check for mistakes around position 13:
# [16:57:44] CC(C)COc1ccc(c1
# [16:57:44] ~~~~~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'CC(C)COc1ccc(c1' for input: 'CC(C)COc1ccc(c1'
# [16:57:44] SMILES Parse Error: extra close parentheses while parsing: CCN(CC(C)C1ccc)C11OCCC2CC3c(C)O)3ccccc3))C2
# [16:57:44] SMILES Parse Error: check for mistakes around position 32:
# [16:57:44] ccc)C11OCCC2CC3c(C)O)3ccccc3))C2
# [16:57:44] ~~~~~~~~~~~~~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'CCN(CC(C)C1ccc)C11OCCC2CC3c(C)O)3ccccc3))C2' for input: 'CCN(CC(C)C1ccc)C11OCCC2CC3c(C)O)3ccccc3))C2'
# [16:57:44] SMILES Parse Error: duplicated ring closure 1 bonds atom 9 to itself for input: 'CC(ccc[N+](=O)[O-])cc11'
# [16:57:44] Can't kekulize mol.  Unkekulized atoms: 8 9 10 11 24
# [16:57:44] SMILES Parse Error: extra open parentheses while parsing: CC(COc1ccc(c1
# [16:57:44] SMILES Parse Error: check for mistakes around position 3:
# [16:57:44] CC(COc1ccc(c1
# [16:57:44] ~~^
# [16:57:44] SMILES Parse Error: extra open parentheses while parsing: CC(COc1ccc(c1
# [16:57:44] SMILES Parse Error: check for mistakes around position 11:
# [16:57:44] CC(COc1ccc(c1
# [16:57:44] ~~~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'CC(COc1ccc(c1' for input: 'CC(COc1ccc(c1'
# [16:57:44] SMILES Parse Error: extra close parentheses while parsing: COc1cc(C))Oc(CC(CO)OCOC(CccO))cc1Oc2ccc(Cl)c(C))C2
# [16:57:44] SMILES Parse Error: check for mistakes around position 10:
# [16:57:44] COc1cc(C))Oc(CC(CO)OCOC(CccO))cc1Oc2ccc(C
# [16:57:44] ~~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'COc1cc(C))Oc(CC(CO)OCOC(CccO))cc1Oc2ccc(Cl)c(C))C2' for input: 'COc1cc(C))Oc(CC(CO)OCOC(CccO))cc1Oc2ccc(Cl)c(C))C2'
# [16:57:44] SMILES Parse Error: extra close parentheses while parsing: CCC(CN(CCCN2CC=c1ccccc2c2ccccF)cc2)CCCcc(F)cc2)CC1
# [16:57:44] SMILES Parse Error: check for mistakes around position 47:
# [16:57:44] cccF)cc2)CCCcc(F)cc2)CC1
# [16:57:44] ~~~~~~~~~~~~~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'CCC(CN(CCCN2CC=c1ccccc2c2ccccF)cc2)CCCcc(F)cc2)CC1' for input: 'CCC(CN(CCCN2CC=c1ccccc2c2ccccF)cc2)CCCcc(F)cc2)CC1'
# [16:57:44] SMILES Parse Error: extra close parentheses while parsing: CCC(=O)c1cccc(CCF)(F)F)cc12NCC=C2c3ccccc3Sc3ccc(N)3ccccC3)C3)CC2=O)Cc(1
# [16:57:44] SMILES Parse Error: check for mistakes around position 23:
# [16:57:44] C(=O)c1cccc(CCF)(F)F)cc12NCC=C2c3ccccc3Sc
# [16:57:44] ~~~~~~~~~~~~~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'CCC(=O)c1cccc(CCF)(F)F)cc12NCC=C2c3ccccc3Sc3ccc(N)3ccccC3)C3)CC2=O)Cc(1' for input: 'CCC(=O)c1cccc(CCF)(F)F)cc12NCC=C2c3ccccc3Sc3ccc(N)3ccccC3)C3)CC2=O)Cc(1'
# [16:57:44] SMILES Parse Error: extra close parentheses while parsing: CCN[C@H]1(N)CCcc(=O)([N-]3)c3c)cC@CCC2)[C@H](CCC(C))[C@HH]1O
# [16:57:44] SMILES Parse Error: check for mistakes around position 31:
# [16:57:44] N)CCcc(=O)([N-]3)c3c)cC@CCC2)[C@H](CCC(C)
# [16:57:44] ~~~~~~~~~~~~~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'CCN[C@H]1(N)CCcc(=O)([N-]3)c3c)cC@CCC2)[C@H](CCC(C))[C@HH]1O' for input: 'CCN[C@H]1(N)CCcc(=O)([N-]3)c3c)cC@CCC2)[C@H](CCC(C))[C@HH]1O'
# [16:57:44] SMILES Parse Error: syntax error while parsing: CCCC@H]1C)O[C@CC(C(=3ccccc3)CC3)C)@@H](Cc1ccccc1)ccccc)cc1
# [16:57:44] SMILES Parse Error: check for mistakes around position 5:
# [16:57:44] CCCC@H]1C)O[C@CC(C(=3ccccc3)CC3)C)@@H](Cc
# [16:57:44] ~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'CCCC@H]1C)O[C@CC(C(=3ccccc3)CC3)C)@@H](Cc1ccccc1)ccccc)cc1' for input: 'CCCC@H]1C)O[C@CC(C(=3ccccc3)CC3)C)@@H](Cc1ccccc1)ccccc)cc1'
# [16:57:44] SMILES Parse Error: extra open parentheses while parsing: O=C(oc2ccc(cc22C(=O)OCccc
# [16:57:44] SMILES Parse Error: check for mistakes around position 4:
# [16:57:44] O=C(oc2ccc(cc22C(=O)OCccc
# [16:57:44] ~~~^
# [16:57:44] SMILES Parse Error: extra open parentheses while parsing: O=C(oc2ccc(cc22C(=O)OCccc
# [16:57:44] SMILES Parse Error: check for mistakes around position 11:
# [16:57:44] O=C(oc2ccc(cc22C(=O)OCccc
# [16:57:44] ~~~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'O=C(oc2ccc(cc22C(=O)OCccc' for input: 'O=C(oc2ccc(cc22C(=O)OCccc'
# [16:57:44] SMILES Parse Error: syntax error while parsing: CC1CC(=)Cc2ccc(C@H]2[C@@H](Occccc1=O)O3)[C@(C)C))C)CO[C@@H](O)C@[C@H]]2O)c11
# [16:57:44] SMILES Parse Error: check for mistakes around position 8:
# [16:57:44] CC1CC(=)Cc2ccc(C@H]2[C@@H](Occccc1=O)O3)[
# [16:57:44] ~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'CC1CC(=)Cc2ccc(C@H]2[C@@H](Occccc1=O)O3)[C@(C)C))C)CO[C@@H](O)C@[C@H]]2O)c11' for input: 'CC1CC(=)Cc2ccc(C@H]2[C@@H](Occccc1=O)O3)[C@(C)C))C)CO[C@@H](O)C@[C@H]]2O)c11'
# [16:57:44] SMILES Parse Error: extra open parentheses while parsing: CCCCCCCOC(cccc(=Oc12
# [16:57:44] SMILES Parse Error: check for mistakes around position 10:
# [16:57:44] CCCCCCCOC(cccc(=Oc12
# [16:57:44] ~~~~~~~~~^
# [16:57:44] SMILES Parse Error: extra open parentheses while parsing: CCCCCCCOC(cccc(=Oc12
# [16:57:44] SMILES Parse Error: check for mistakes around position 15:
# [16:57:44] CCCCCCCOC(cccc(=Oc12
# [16:57:44] ~~~~~~~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCOC(cccc(=Oc12' for input: 'CCCCCCCOC(cccc(=Oc12'
# [16:57:44] SMILES Parse Error: syntax error while parsing: C=C(1cc2cccc2cC1Ccc(S(=O)(=O)NC(=(=O)Nc2ccc(c2)CC=O)C3)ccc221
# [16:57:44] SMILES Parse Error: check for mistakes around position 5:
# [16:57:44] C=C(1cc2cccc2cC1Ccc(S(=O)(=O)NC(=(=O)Nc2c
# [16:57:44] ~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'C=C(1cc2cccc2cC1Ccc(S(=O)(=O)NC(=(=O)Nc2ccc(c2)CC=O)C3)ccc221' for input: 'C=C(1cc2cccc2cC1Ccc(S(=O)(=O)NC(=(=O)Nc2ccc(c2)CC=O)C3)ccc221'
# [16:57:44] SMILES Parse Error: extra open parentheses while parsing: CC(C)c1ccc(C1ccccc1
# [16:57:44] SMILES Parse Error: check for mistakes around position 11:
# [16:57:44] CC(C)c1ccc(C1ccccc1
# [16:57:44] ~~~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'CC(C)c1ccc(C1ccccc1' for input: 'CC(C)c1ccc(C1ccccc1'
# [16:57:44] SMILES Parse Error: syntax error while parsing: O=C(O[C@H](CO)[1cS)(OC)SC[C@H](OCO
# [16:57:44] SMILES Parse Error: check for mistakes around position 18:
# [16:57:44] O=C(O[C@H](CO)[1cS)(OC)SC[C@H](OCO
# [16:57:44] ~~~~~~~~~~~~~~~~~^
# [16:57:44] SMILES Parse Error: extra open parentheses while parsing: O=C(O[C@H](CO)[1cS)(OC)SC[C@H](OCO
# [16:57:44] SMILES Parse Error: check for mistakes around position 4:
# [16:57:44] O=C(O[C@H](CO)[1cS)(OC)SC[C@H](OCO
# [16:57:44] ~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'O=C(O[C@H](CO)[1cS)(OC)SC[C@H](OCO' for input: 'O=C(O[C@H](CO)[1cS)(OC)SC[C@H](OCO'
# [16:57:44] SMILES Parse Error: extra open parentheses while parsing: Cc1ccc2c(cc1C(=O)Cc1ccc(c1)OCc1ccccc12
# [16:57:44] SMILES Parse Error: check for mistakes around position 9:
# [16:57:44] Cc1ccc2c(cc1C(=O)Cc1ccc(c1)OCc1ccccc12
# [16:57:44] ~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'Cc1ccc2c(cc1C(=O)Cc1ccc(c1)OCc1ccccc12' for input: 'Cc1ccc2c(cc1C(=O)Cc1ccc(c1)OCc1ccccc12'
# [16:57:44] SMILES Parse Error: unclosed ring for input: 'NCCccccOCcc1O'
# [16:57:44] SMILES Parse Error: syntax error while parsing: COc1ccc(C((C(=O)Oc2nc[nH]c2cccs2)c(CC)n1
# [16:57:44] SMILES Parse Error: check for mistakes around position 11:
# [16:57:44] COc1ccc(C((C(=O)Oc2nc[nH]c2cccs2)c(CC)n1
# [16:57:44] ~~~~~~~~~~^
# [16:57:44] SMILES Parse Error: extra open parentheses while parsing: COc1ccc(C((C(=O)Oc2nc[nH]c2cccs2)c(CC)n1
# [16:57:44] SMILES Parse Error: check for mistakes around position 8:
# [16:57:44] COc1ccc(C((C(=O)Oc2nc[nH]c2cccs2)c(CC)n1
# [16:57:44] ~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'COc1ccc(C((C(=O)Oc2nc[nH]c2cccs2)c(CC)n1' for input: 'COc1ccc(C((C(=O)Oc2nc[nH]c2cccs2)c(CC)n1'
# [16:57:44] SMILES Parse Error: extra close parentheses while parsing: CCOC(=O)c1ccc(C)C)C)C)cc11
# [16:57:44] SMILES Parse Error: check for mistakes around position 18:
# [16:57:44] CCOC(=O)c1ccc(C)C)C)C)cc11
# [16:57:44] ~~~~~~~~~~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'CCOC(=O)c1ccc(C)C)C)C)cc11' for input: 'CCOC(=O)c1ccc(C)C)C)C)cc11'
# [16:57:44] SMILES Parse Error: syntax error while parsing: CCc1cn((cc1)[C-]
# [16:57:44] SMILES Parse Error: check for mistakes around position 8:
# [16:57:44] CCc1cn((cc1)[C-]
# [16:57:44] ~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'CCc1cn((cc1)[C-]' for input: 'CCc1cn((cc1)[C-]'
# [16:57:44] SMILES Parse Error: extra close parentheses while parsing: COC1cccCN2CccCCccccccccCCc3ccccc3)2))c(c1
# [16:57:44] SMILES Parse Error: check for mistakes around position 34:
# [16:57:44] CCccccccccCCc3ccccc3)2))c(c1
# [16:57:44] ~~~~~~~~~~~~~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'COC1cccCN2CccCCccccccccCCc3ccccc3)2))c(c1' for input: 'COC1cccCN2CccCCccccccccCCc3ccccc3)2))c(c1'
# [16:57:44] SMILES Parse Error: syntax error while parsing: CCN+](CCO)2cccF)cc2ccc(F)cF)F)c1)C(=O)c2ccccc2)c11
# [16:57:44] SMILES Parse Error: check for mistakes around position 4:
# [16:57:44] CCN+](CCO)2cccF)cc2ccc(F)cF)F)c1)C(=O)c2c
# [16:57:44] ~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'CCN+](CCO)2cccF)cc2ccc(F)cF)F)c1)C(=O)c2ccccc2)c11' for input: 'CCN+](CCO)2cccF)cc2ccc(F)cF)F)c1)C(=O)c2ccccc2)c11'
# [16:57:44] SMILES Parse Error: extra close parentheses while parsing: COc1ccccc=O)[O-])cc(N1
# [16:57:44] SMILES Parse Error: check for mistakes around position 12:
# [16:57:44] COc1ccccc=O)[O-])cc(N1
# [16:57:44] ~~~~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'COc1ccccc=O)[O-])cc(N1' for input: 'COc1ccccc=O)[O-])cc(N1'
# [16:57:44] SMILES Parse Error: extra close parentheses while parsing: CCC(C)CC=O)N[C@@H]1CC[C@H](CN2CC[C@H]2SC(C@@H]1C(=O)O)C1=O)NCC=O)OCCNC((@3ccc(N)=O)O)cc3)C[C@H](2)C(=O)N2C@H]](CCC(=O)[
# [16:57:44] SMILES Parse Error: check for mistakes around position 11:
# [16:57:44] CCC(C)CC=O)N[C@@H]1CC[C@H](CN2CC[C@H]2SC(
# [16:57:44] ~~~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'CCC(C)CC=O)N[C@@H]1CC[C@H](CN2CC[C@H]2SC(C@@H]1C(=O)O)C1=O)NCC=O)OCCNC((@3ccc(N)=O)O)cc3)C[C@H](2)C(=O)N2C@H]](CCC(=O)[' for input: 'CCC(C)CC=O)N[C@@H]1CC[C@H](CN2CC[C@H]2SC(C@@H]1C(=O)O)C1=O)NCC=O)OCCNC((@3ccc(N)=O)O)cc3)C[C@H](2)C(=O)N2C@H]](CCC(=O)['
# [16:57:44] SMILES Parse Error: unclosed ring for input: 'CCC(CO)c1cccc(Br)c11'
# [16:57:44] SMILES Parse Error: unclosed ring for input: 'CCOC(=O)Cc1ccc(C(F)(F)F)cc21'
# [16:57:44] SMILES Parse Error: extra close parentheses while parsing: CCC(CC)OCC=O)CC(=O)OC(=)c1cccc2Sc1c1
# [16:57:44] SMILES Parse Error: check for mistakes around position 13:
# [16:57:44] CCC(CC)OCC=O)CC(=O)OC(=)c1cccc2Sc1c1
# [16:57:44] ~~~~~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'CCC(CC)OCC=O)CC(=O)OC(=)c1cccc2Sc1c1' for input: 'CCC(CC)OCC=O)CC(=O)OC(=)c1cccc2Sc1c1'
# [16:57:44] SMILES Parse Error: extra close parentheses while parsing: Nc1ccc-c2ccccc2c[nH]cccc32)nH]1
# [16:57:44] SMILES Parse Error: check for mistakes around position 27:
# [16:57:44] -c2ccccc2c[nH]cccc32)nH]1
# [16:57:44] ~~~~~~~~~~~~~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'Nc1ccc-c2ccccc2c[nH]cccc32)nH]1' for input: 'Nc1ccc-c2ccccc2c[nH]cccc32)nH]1'
# [16:57:44] SMILES Parse Error: extra close parentheses while parsing: CN1CCC=O)Nc1cccc2nc(=O)n2ccnH]c2C
# [16:57:44] SMILES Parse Error: check for mistakes around position 9:
# [16:57:44] CN1CCC=O)Nc1cccc2nc(=O)n2ccnH]c2C
# [16:57:44] ~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'CN1CCC=O)Nc1cccc2nc(=O)n2ccnH]c2C' for input: 'CN1CCC=O)Nc1cccc2nc(=O)n2ccnH]c2C'
# [16:57:44] SMILES Parse Error: syntax error while parsing: CC(CC(c1c]ccc1)CCCCc2cccc(O)cc2)C(ccccC2)c2cc
# [16:57:44] SMILES Parse Error: check for mistakes around position 10:
# [16:57:44] CC(CC(c1c]ccc1)CCCCc2cccc(O)cc2)C(ccccC2)
# [16:57:44] ~~~~~~~~~^
# [16:57:44] SMILES Parse Error: extra open parentheses while parsing: CC(CC(c1c]ccc1)CCCCc2cccc(O)cc2)C(ccccC2)c2cc
# [16:57:44] SMILES Parse Error: check for mistakes around position 3:
# [16:57:44] CC(CC(c1c]ccc1)CCCCc2cccc(O)cc2)C(ccccC2)
# [16:57:44] ~~^
# [16:57:44] SMILES Parse Error: extra open parentheses while parsing: CC(CC(c1c]ccc1)CCCCc2cccc(O)cc2)C(ccccC2)c2cc
# [16:57:44] SMILES Parse Error: check for mistakes around position 6:
# [16:57:44] CC(CC(c1c]ccc1)CCCCc2cccc(O)cc2)C(ccccC2)
# [16:57:44] ~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'CC(CC(c1c]ccc1)CCCCc2cccc(O)cc2)C(ccccC2)c2cc' for input: 'CC(CC(c1c]ccc1)CCCCc2cccc(O)cc2)C(ccccC2)c2cc'
# [16:57:44] SMILES Parse Error: extra close parentheses while parsing: CC(Cl)cBr)
# [16:57:44] SMILES Parse Error: check for mistakes around position 10:
# [16:57:44] CC(Cl)cBr)
# [16:57:44] ~~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'CC(Cl)cBr)' for input: 'CC(Cl)cBr)'
# [16:57:44] SMILES Parse Error: extra close parentheses while parsing: Cc1ccccccccc1=O)[nH]1
# [16:57:44] SMILES Parse Error: check for mistakes around position 16:
# [16:57:44] Cc1ccccccccc1=O)[nH]1
# [16:57:44] ~~~~~~~~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'Cc1ccccccccc1=O)[nH]1' for input: 'Cc1ccccccccc1=O)[nH]1'
# [16:57:44] SMILES Parse Error: syntax error while parsing: Nc1ccc((C(OC)c1
# [16:57:44] SMILES Parse Error: check for mistakes around position 8:
# [16:57:44] Nc1ccc((C(OC)c1
# [16:57:44] ~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'Nc1ccc((C(OC)c1' for input: 'Nc1ccc((C(OC)c1'
# [16:57:44] SMILES Parse Error: syntax error while parsing: CCC(=O)Oc1ccc(CCCsc2[C@]2])CC1=O
# [16:57:44] SMILES Parse Error: check for mistakes around position 26:
# [16:57:44] O)Oc1ccc(CCCsc2[C@]2])CC1=O
# [16:57:44] ~~~~~~~~~~~~~~~~~~~~^
# [16:57:44] SMILES Parse Error: extra open parentheses while parsing: CCC(=O)Oc1ccc(CCCsc2[C@]2])CC1=O
# [16:57:44] SMILES Parse Error: check for mistakes around position 14:
# [16:57:44] CCC(=O)Oc1ccc(CCCsc2[C@]2])CC1=O
# [16:57:44] ~~~~~~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'CCC(=O)Oc1ccc(CCCsc2[C@]2])CC1=O' for input: 'CCC(=O)Oc1ccc(CCCsc2[C@]2])CC1=O'
# [16:57:44] SMILES Parse Error: extra close parentheses while parsing: CN(C)CCCCCNc2ccccc2)ccc2cc2c(cc2)CC(N)=O)cc1
# [16:57:44] SMILES Parse Error: check for mistakes around position 20:
# [16:57:44] CN(C)CCCCCNc2ccccc2)ccc2cc2c(cc2)CC(N)=O)
# [16:57:44] ~~~~~~~~~~~~~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'CN(C)CCCCCNc2ccccc2)ccc2cc2c(cc2)CC(N)=O)cc1' for input: 'CN(C)CCCCCNc2ccccc2)ccc2cc2c(cc2)CC(N)=O)cc1'
# [16:57:44] SMILES Parse Error: syntax error while parsing: CN(C=O)[C@@H]1C(=O)cNc(C(=@@]](O)C[CO)[C@])cCcccccc2cH]c3C(C)C)C@H]12
# [16:57:44] SMILES Parse Error: check for mistakes around position 27:
# [16:57:44] )[C@@H]1C(=O)cNc(C(=@@]](O)C[CO)[C@])cCcc
# [16:57:44] ~~~~~~~~~~~~~~~~~~~~^
# [16:57:44] SMILES Parse Error: extra open parentheses while parsing: CN(C=O)[C@@H]1C(=O)cNc(C(=@@]](O)C[CO)[C@])cCcccccc2cH]c3C(C)C)C@H]12
# [16:57:44] SMILES Parse Error: check for mistakes around position 23:
# [16:57:44] (C=O)[C@@H]1C(=O)cNc(C(=@@]](O)C[CO)[C@])
# [16:57:44] ~~~~~~~~~~~~~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'CN(C=O)[C@@H]1C(=O)cNc(C(=@@]](O)C[CO)[C@])cCcccccc2cH]c3C(C)C)C@H]12' for input: 'CN(C=O)[C@@H]1C(=O)cNc(C(=@@]](O)C[CO)[C@])cCcccccc2cH]c3C(C)C)C@H]12'
# [16:57:44] SMILES Parse Error: extra close parentheses while parsing: CCCCccc(C(cc1)C(=O)c1cccCO)cCC=O)O)c(1
# [16:57:44] SMILES Parse Error: check for mistakes around position 33:
# [16:57:44] 1)C(=O)c1cccCO)cCC=O)O)c(1
# [16:57:44] ~~~~~~~~~~~~~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'CCCCccc(C(cc1)C(=O)c1cccCO)cCC=O)O)c(1' for input: 'CCCCccc(C(cc1)C(=O)c1cccCO)cCC=O)O)c(1'
# [16:57:44] SMILES Parse Error: extra open parentheses while parsing: CC(CCCCCCC(=O)c1ccc(C(F)(F)F)cc1
# [16:57:44] SMILES Parse Error: check for mistakes around position 3:
# [16:57:44] CC(CCCCCCC(=O)c1ccc(C(F)(F)F)cc1
# [16:57:44] ~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'CC(CCCCCCC(=O)c1ccc(C(F)(F)F)cc1' for input: 'CC(CCCCCCC(=O)c1ccc(C(F)(F)F)cc1'
# [16:57:44] SMILES Parse Error: extra close parentheses while parsing: Cc1occ(S(=O)(=O)Nc2cccc(OC)cc3cCC)cc3)cC1
# [16:57:44] SMILES Parse Error: check for mistakes around position 38:
# [16:57:44] c2cccc(OC)cc3cCC)cc3)cC1
# [16:57:44] ~~~~~~~~~~~~~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'Cc1occ(S(=O)(=O)Nc2cccc(OC)cc3cCC)cc3)cC1' for input: 'Cc1occ(S(=O)(=O)Nc2cccc(OC)cc3cCC)cc3)cC1'
# [16:57:44] SMILES Parse Error: extra close parentheses while parsing: CCCCCCCCCC)CC1
# [16:57:44] SMILES Parse Error: check for mistakes around position 11:
# [16:57:44] CCCCCCCCCC)CC1
# [16:57:44] ~~~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCCCC)CC1' for input: 'CCCCCCCCCC)CC1'
# [16:57:44] SMILES Parse Error: syntax error while parsing: CCC(=O)NCCC@H]1CCN(CCC1)Cc1ccc[nH]()ccC)cCCc12
# [16:57:44] SMILES Parse Error: check for mistakes around position 12:
# [16:57:44] CCC(=O)NCCC@H]1CCN(CCC1)Cc1ccc[nH]()ccC)c
# [16:57:44] ~~~~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'CCC(=O)NCCC@H]1CCN(CCC1)Cc1ccc[nH]()ccC)cCCc12' for input: 'CCC(=O)NCCC@H]1CCN(CCC1)Cc1ccc[nH]()ccC)cCCc12'
# [16:57:44] SMILES Parse Error: extra close parentheses while parsing: COc1ccccc1Nc1ccc[C@H](N)[C@H](CC(c3ccccc3))[C@@](CN2CCCCC3)C2)N12CC(=)O)CO2
# [16:57:44] SMILES Parse Error: check for mistakes around position 62:
# [16:57:44] ))[C@@](CN2CCCCC3)C2)N12CC(=)O)CO2
# [16:57:44] ~~~~~~~~~~~~~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'COc1ccccc1Nc1ccc[C@H](N)[C@H](CC(c3ccccc3))[C@@](CN2CCCCC3)C2)N12CC(=)O)CO2' for input: 'COc1ccccc1Nc1ccc[C@H](N)[C@H](CC(c3ccccc3))[C@@](CN2CCCCC3)C2)N12CC(=)O)CO2'
# [16:57:44] SMILES Parse Error: syntax error while parsing: Cc1nnc(([C+](=O)[)[C-])c1
# [16:57:44] SMILES Parse Error: check for mistakes around position 8:
# [16:57:44] Cc1nnc(([C+](=O)[)[C-])c1
# [16:57:44] ~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'Cc1nnc(([C+](=O)[)[C-])c1' for input: 'Cc1nnc(([C+](=O)[)[C-])c1'
# [16:57:44] SMILES Parse Error: extra close parentheses while parsing: CCCCCOC(c1ccccF)ccF)F)F)c1
# [16:57:44] SMILES Parse Error: check for mistakes around position 20:
# [16:57:44] CCCCCOC(c1ccccF)ccF)F)F)c1
# [16:57:44] ~~~~~~~~~~~~~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'CCCCCOC(c1ccccF)ccF)F)F)c1' for input: 'CCCCCOC(c1ccccF)ccF)F)F)c1'
# [16:57:44] SMILES Parse Error: syntax error while parsing: CCO=C(C1ccccccccc[N+](=O-])cC(O)=O)c1
# [16:57:44] SMILES Parse Error: check for mistakes around position 26:
# [16:57:44] (C1ccccccccc[N+](=O-])cC(O)=O)c1
# [16:57:44] ~~~~~~~~~~~~~~~~~~~~^
# [16:57:44] SMILES Parse Error: extra open parentheses while parsing: CCO=C(C1ccccccccc[N+](=O-])cC(O)=O)c1
# [16:57:44] SMILES Parse Error: check for mistakes around position 6:
# [16:57:44] CCO=C(C1ccccccccc[N+](=O-])cC(O)=O)c1
# [16:57:44] ~~~~~^
# [16:57:44] SMILES Parse Error: extra open parentheses while parsing: CCO=C(C1ccccccccc[N+](=O-])cC(O)=O)c1
# [16:57:44] SMILES Parse Error: check for mistakes around position 22:
# [16:57:44] CO=C(C1ccccccccc[N+](=O-])cC(O)=O)c1
# [16:57:44] ~~~~~~~~~~~~~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'CCO=C(C1ccccccccc[N+](=O-])cC(O)=O)c1' for input: 'CCO=C(C1ccccccccc[N+](=O-])cC(O)=O)c1'
# [16:57:44] SMILES Parse Error: syntax error while parsing: [F-+]]1cccccCl)c1
# [16:57:44] SMILES Parse Error: check for mistakes around position 4:
# [16:57:44] [F-+]]1cccccCl)c1
# [16:57:44] ~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES '[F-+]]1cccccCl)c1' for input: '[F-+]]1cccccCl)c1'
# [16:57:44] SMILES Parse Error: syntax error while parsing: O=CN+]([O-])c1cccO)ccccO[C@H]2C[C@@H](CCC)C)[C@H](C)[C@H](O)[C@@]((O)[C@ccccO))c2)[C@H]22Oc1ccccc1C
# [16:57:44] SMILES Parse Error: check for mistakes around position 5:
# [16:57:44] O=CN+]([O-])c1cccO)ccccO[C@H]2C[C@@H](CCC
# [16:57:44] ~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'O=CN+]([O-])c1cccO)ccccO[C@H]2C[C@@H](CCC)C)[C@H](C)[C@H](O)[C@@]((O)[C@ccccO))c2)[C@H]22Oc1ccccc1C' for input: 'O=CN+]([O-])c1cccO)ccccO[C@H]2C[C@@H](CCC)C)[C@H](C)[C@H](O)[C@@]((O)[C@ccccO))c2)[C@H]22Oc1ccccc1C'
# [16:57:44] SMILES Parse Error: extra close parentheses while parsing: Cc1cc(C)=O)c2(Cc2ccc(F)cc2F)n(CC)F)cc2F)cF)c1F
# [16:57:44] SMILES Parse Error: check for mistakes around position 11:
# [16:57:44] Cc1cc(C)=O)c2(Cc2ccc(F)cc2F)n(CC)F)cc2F)c
# [16:57:44] ~~~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'Cc1cc(C)=O)c2(Cc2ccc(F)cc2F)n(CC)F)cc2F)cF)c1F' for input: 'Cc1cc(C)=O)c2(Cc2ccc(F)cc2F)n(CC)F)cc2F)cF)c1F'
# [16:57:44] SMILES Parse Error: syntax error while parsing: CCCC1(C)CC2=NC((=O)N2C)CC(CCC(=O)O2ccc(CCCC21
# [16:57:44] SMILES Parse Error: check for mistakes around position 16:
# [16:57:44] CCCC1(C)CC2=NC((=O)N2C)CC(CCC(=O)O2ccc(CC
# [16:57:44] ~~~~~~~~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'CCCC1(C)CC2=NC((=O)N2C)CC(CCC(=O)O2ccc(CCCC21' for input: 'CCCC1(C)CC2=NC((=O)N2C)CC(CCC(=O)O2ccc(CCCC21'
# [16:57:44] SMILES Parse Error: extra open parentheses while parsing: O=C(O)c1ccc(c1F
# [16:57:44] SMILES Parse Error: check for mistakes around position 12:
# [16:57:44] O=C(O)c1ccc(c1F
# [16:57:44] ~~~~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'O=C(O)c1ccc(c1F' for input: 'O=C(O)c1ccc(c1F'
# [16:57:44] SMILES Parse Error: extra close parentheses while parsing: CC(CNC(=N)CN1CCN1CC=NCc2ccccc(C)F)(F)F)cc32)CCccccn1
# [16:57:44] SMILES Parse Error: check for mistakes around position 39:
# [16:57:44] C=NCc2ccccc(C)F)(F)F)cc32)CCccccn1
# [16:57:44] ~~~~~~~~~~~~~~~~~~~~^
# [16:57:44] SMILES Parse Error: Failed parsing SMILES 'CC(CNC(=N)CN1CCN1CC=NCc2ccccc(C)F)(F)F)cc32)CCccccn1' for input: 'CC(CNC(=N)CN1CCN1CC=NCc2ccccc(C)F)(F)F)cc32)CCccccn1'

# %% [markdown]
# ---
# ## 12. Optimized Candidate Molecules
# Score generated molecules through all pipelines (toxicity, binding affinity, Lipinski) and rank the best candidates.

# %%
# ─── Score Generated Molecules Through All Pipelines ───

def lipinski_score(smiles):
    """Return number of Lipinski Rule-of-5 violations."""
    mol = Chem.MolFromSmiles(smiles)
    if mol is None:
        return 5
    violations = 0
    if Descriptors.MolWt(mol) > 500: violations += 1
    if Descriptors.MolLogP(mol) > 5: violations += 1
    if Descriptors.NumHDonors(mol) > 5: violations += 1
    if Descriptors.NumHAcceptors(mol) > 10: violations += 1
    return violations


def score_molecule(smiles, tox_model, egnn_model, device):
    """Score a molecule through toxicity and binding affinity predictors."""
    result = {'smiles': smiles}

    mol = Chem.MolFromSmiles(smiles)
    if mol is None:
        return None

    # Molecular descriptors
    result['MW'] = Descriptors.MolWt(mol)
    result['LogP'] = Descriptors.MolLogP(mol)
    result['TPSA'] = Descriptors.TPSA(mol)
    result['HBD'] = Descriptors.NumHDonors(mol)
    result['HBA'] = Descriptors.NumHAcceptors(mol)
    result['lipinski_violations'] = lipinski_score(smiles)

    # Build graph
    graph = smiles_to_graph(smiles)
    if graph is None:
        return None

    # Toxicity prediction
    tox_model.eval()
    batch = Batch.from_data_list([graph]).to(device)
    with torch.no_grad():
        tox_logit = tox_model(batch).item()
        result['tox_prob'] = torch.sigmoid(torch.tensor(tox_logit)).item()

    # Binding affinity prediction
    egnn_model.eval()
    with torch.no_grad():
        aff_pred = egnn_model(batch.x, batch.edge_index, batch.batch).item()
        result['pred_affinity'] = aff_pred

    return result


# Score all valid generated molecules
scored_molecules = []
for smi in tqdm(unique_smiles, desc='Scoring molecules'):
    result = score_molecule(smi, tox_model, egnn_model, DEVICE)
    if result is not None:
        scored_molecules.append(result)

scored_df = pd.DataFrame(scored_molecules)
print(f'Successfully scored: {len(scored_df)} molecules')
scored_df.head()
# Out:
# Scoring molecules:   0%|          | 0/9 [00:00<?, ?it/s]
# Successfully scored: 9 molecules
#              smiles       MW     LogP  TPSA  HBD  HBA  lipinski_violations  \
# 0          CC(Cl)Br  143.411  1.96610   0.0    0    0                    0
# 1           CC(=O)O   60.052  0.09090  37.3    1    1                    0
# 2  CN([O-])c1ccccc1  122.147  1.62060  26.3    0    2                    0
# 3        Cc1ccccc1C  106.168  2.30344   0.0    0    0                    0
# 4         CC(Cl)CCl  112.987  1.85250   0.0    0    0                    0
#
#    tox_prob  pred_affinity
# 0  0.024629       8.432832
# 1  0.052465       8.447102
# 2  0.295246       8.427745
# 3  0.051294       8.426774
# 4  0.057441       8.427188

# %%
# ─── Rank and Select Optimized Candidates ───

# Composite optimization score:
# Higher affinity + lower toxicity + fewer Lipinski violations = better
scored_df['optimization_score'] = (
    scored_df['pred_affinity'] * 0.4                          # higher is better
    - scored_df['tox_prob'] * 3.0                             # lower is better
    - scored_df['lipinski_violations'] * 1.0                  # fewer violations
)

# Rank
scored_df = scored_df.sort_values('optimization_score', ascending=False).reset_index(drop=True)

print('\n=== TOP 15 OPTIMIZED CANDIDATE MOLECULES ===')
top_cols = ['smiles', 'MW', 'LogP', 'tox_prob', 'pred_affinity',
            'lipinski_violations', 'optimization_score']
display_df = scored_df[top_cols].head(15)
display_df.columns = ['SMILES', 'MW', 'LogP', 'Tox Prob', 'Pred Affinity',
                       'Lipinski Viol.', 'Opt. Score']
print(display_df.to_string(index=False))
# Out:
# === TOP 15 OPTIMIZED CANDIDATE MOLECULES ===
#                   SMILES      MW    LogP  Tox Prob  Pred Affinity  Lipinski Viol.  Opt. Score
#                 CC(Cl)Br 143.411 1.96610  0.024629       8.432832               0    3.299245
#                  CC(=O)O  60.052 0.09090  0.052465       8.447102               0    3.221445
#               Cc1ccccc1C 106.168 2.30344  0.051294       8.426774               0    3.216828
#                CC(Cl)CCl 112.987 1.85250  0.057441       8.427188               0    3.198551
#               CC(CO)CCCl 122.595 1.24370  0.115967       8.424623               0    3.021949
#                  C=C(O)O  60.052 0.57360  0.130912       8.447811               0    2.986388
#         CN([O-])c1ccccc1 122.147 1.62060  0.295246       8.427745               0    2.485359
# CCCCc1ccc(CC=O)c2ccccc12 226.319 3.92380  0.447991       8.420007               0    2.024030
#  CCC1=CC=C(O)CN=CC=CC=C1 189.258 2.96150  0.748543       8.426360               0    1.124916

# %%
# ─── Visualize Optimized Candidates ───

fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# 1. Toxicity vs Affinity scatter
sc = axes[0, 0].scatter(scored_df['pred_affinity'], scored_df['tox_prob'],
                         c=scored_df['optimization_score'], cmap='RdYlGn',
                         edgecolors='black', linewidths=0.3, alpha=0.7)
axes[0, 0].set_xlabel('Predicted Binding Affinity')
axes[0, 0].set_ylabel('Toxicity Probability')
axes[0, 0].set_title('Affinity vs Toxicity (color=Opt Score)')
plt.colorbar(sc, ax=axes[0, 0])

# 2. Optimization score distribution
axes[0, 1].hist(scored_df['optimization_score'], bins=30, color='seagreen', edgecolor='black', alpha=0.7)
axes[0, 1].axvline(x=scored_df['optimization_score'].quantile(0.9), color='red',
                     linestyle='--', label='Top 10%')
axes[0, 1].set_xlabel('Optimization Score')
axes[0, 1].set_title('Optimization Score Distribution')
axes[0, 1].legend()

# 3. MW vs LogP (drug-likeness)
axes[1, 0].scatter(scored_df['MW'], scored_df['LogP'],
                    c=scored_df['lipinski_violations'], cmap='coolwarm',
                    edgecolors='black', linewidths=0.3, alpha=0.7)
axes[1, 0].axhline(y=5, color='red', linestyle='--', alpha=0.5)
axes[1, 0].axvline(x=500, color='red', linestyle='--', alpha=0.5)
axes[1, 0].set_xlabel('Molecular Weight')
axes[1, 0].set_ylabel('LogP')
axes[1, 0].set_title('Drug-likeness Space (Ro5 boundaries in red)')

# 4. Lipinski violations
scored_df['lipinski_violations'].value_counts().sort_index().plot.bar(
    ax=axes[1, 1], color='coral', edgecolor='black')
axes[1, 1].set_xlabel('Number of Lipinski Violations')
axes[1, 1].set_ylabel('Count')
axes[1, 1].set_title('Lipinski Violations Distribution')
axes[1, 1].tick_params(axis='x', rotation=0)

plt.tight_layout()
plt.show()

# %%
# ─── Draw Top Candidate Molecules ───

top_smiles = scored_df.head(8)['smiles'].tolist()
top_mols = [Chem.MolFromSmiles(s) for s in top_smiles if Chem.MolFromSmiles(s) is not None]

if top_mols:
    legends = [f'Score: {scored_df.iloc[i]["optimization_score"]:.2f}' for i in range(len(top_mols))]
    img = Draw.MolsToGridImage(top_mols, molsPerRow=4, subImgSize=(400, 300), legends=legends)
    display(img)
else:
    print('No valid molecules to draw. Try generating more or adjusting temperature.')

# %%
# ─── Score Existing Drug Candidates from drug_cleaned ───

# Also evaluate top docking-scored molecules from existing libraries
top_docking = drug_cleaned.nsmallest(100, 'score')  # most negative = best docking

existing_scored = []
for _, row in tqdm(top_docking.iterrows(), total=len(top_docking), desc='Scoring existing drugs'):
    result = score_molecule(row['SMILES'], tox_model, egnn_model, DEVICE)
    if result is not None:
        result['docking_score'] = row['score']
        result['target'] = row['target']
        existing_scored.append(result)

existing_df = pd.DataFrame(existing_scored)
existing_df['optimization_score'] = (
    existing_df['pred_affinity'] * 0.4
    - existing_df['tox_prob'] * 3.0
    - existing_df['lipinski_violations'] * 1.0
)
existing_df = existing_df.sort_values('optimization_score', ascending=False)

print('\n=== TOP 10 EXISTING DRUG CANDIDATES (from docking library) ===')
print(existing_df[['smiles', 'target', 'docking_score', 'tox_prob',
                    'pred_affinity', 'lipinski_violations', 'optimization_score']].head(10).to_string(index=False))
# Out:
# Scoring existing drugs:   0%|          | 0/100 [00:00<?, ?it/s]
# === TOP 10 EXISTING DRUG CANDIDATES (from docking library) ===
#                                              smiles target  docking_score  tox_prob  pred_affinity  lipinski_violations  optimization_score
#                            Cc1nc(CC(=O)NCC(=O)O)cs1    ada      -124.9296  0.106584       8.422790                    0            3.049364
#                 CCCCC(NC(=O)CNC(=O)NC1CCCCC1)C(=O)O    ada      -124.8712  0.110425       8.418933                    0            3.036298
#   CC(C)C[C@H](NC(=O)CNC(=O)CS(=O)(=O)C1CCCC1)C(=O)O    ada      -124.9235  0.113128       8.420014                    0            3.028622
#                           CCCCC(NC1CCC1C1CC1)C(=O)O    ada      -125.0177  0.112208       8.411458                    0            3.027959
#                       CC(O)(CNC(=O)CC1CCCCC1)C(=O)O    ada      -124.8907  0.113708       8.418389                    0            3.026233
#                 COc1cccc(C(C)N2CCN(CCCC(=O)O)CC2)c1    ada      -124.9008  0.115540       8.414785                    0            3.019295
# CC(=O)N[C@@H](CC(=O)N[C@@H](Cc1ccccc1)C(=O)O)C(=O)O    ada      -124.8157  0.123568       8.427226                    0            3.000187
#        CCN(CC)S(=O)(=O)CC(=O)NC(C(=O)O)c1cccc(C)c1C    ada      -125.0260  0.129655       8.423182                    0            2.980307
#                       CC(CNC(=O)NCCC(=O)O)Oc1ccccc1    ada      -125.0395  0.130816       8.425213                    0            2.977638
#            Cc1nn(C)cc1S(=O)(=O)N[C@H](CC(C)C)C(=O)O    ada      -124.9673  0.131272       8.421535                    0            2.974797

# %%
# ─── Export Optimized Candidates ───

# Save generated candidates
scored_df.to_csv('/content/generated_candidates.csv', index=False)
print(f'Saved {len(scored_df)} generated candidates to generated_candidates.csv')

# Save existing library ranked candidates
existing_df.to_csv('/content/existing_candidates_ranked.csv', index=False)
print(f'Saved {len(existing_df)} existing ranked candidates to existing_candidates_ranked.csv')

# Save model checkpoints
torch.save({
    'foundation_model': foundation_model.state_dict(),
    'diffusion_engine': diffusion_engine.state_dict(),
    'smiles_decoder': smiles_decoder.state_dict(),
    'egnn_model': egnn_model.state_dict(),
    'tox_model': tox_model.state_dict(),
}, '/content/drug_discovery_models.pt')
print('All model checkpoints saved to /content/drug_discovery_models.pt')
# Out:
# Saved 9 generated candidates to generated_candidates.csv
# Saved 100 existing ranked candidates to existing_candidates_ranked.csv
# All model checkpoints saved to /content/drug_discovery_models.pt
